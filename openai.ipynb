# %%
import requests
import xmltodict
import os
import json
import numpy as np
from dotenv import load_dotenv
from openai import OpenAI

# .env 파일에서 API 키 불러오기
load_dotenv()
kipris_key = os.getenv("KIPRIS_API_KEY")
openai_api_key = os.getenv("OPENAI_API_KEY")

# OpenAI 클라이언트 초기화
client = OpenAI(api_key=openai_api_key)

# 사용자 질문에서 키워드 추출
def extract_keywords_from_question(question):
  prompt = f"""
너는 특허 검색을 도와주는 AI야. 사용자가 질문한 문장에서 중요도에 따라 키워드를 구분해서 추출해줘.

조건:
- 중요 키워드(핵심)와 보조 키워드(있으면 좋음)를 구분해줘.
- JSON 형식으로 출력해줘. (주요 키워드: [], 보조 키워드: [])

질문: "{question}"
"""

  completion = client.chat.completions.create(
      model="gpt-4",
      messages=[
        {"role": "system", "content": "당신은 특허 검색 키워드 추출 전문가입니다."},
        {"role": "user", "content": prompt}
      ]
  )

  keywords_json = completion.choices[0].message.content.strip()

  try:
    keywords_dict = json.loads(keywords_json)
  except json.JSONDecodeError:
    keywords = [kw.strip() for kw in keywords_json.split(",")]
    keywords_dict = {"주요 키워드": keywords, "보조 키워드": []}

  return keywords_dict

# 특허 검색
def search_all_patents(keyword):
  all_patents = []
  page_no = 1

  while True:
    url = (
      f"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getWordSearch"
      f"?word={keyword}&year=0&patent=Y&utility=Y"
      f"&numOfRows=100&pageNo={page_no}&ServiceKey={kipris_key}"
    )
    response = requests.get(url)

    if response.status_code == 200:
      xml_data = xmltodict.parse(response.content)
      body = xml_data['response']['body']
      items = body['items'].get('item')

      if not items:
        break

      if isinstance(items, dict):
        items = [items]

      all_patents.extend(items)

      if 'totalCount' in body:
        total_count = int(body['totalCount'])
        if len(all_patents) >= total_count:
          break
      else:
        break

      page_no += 1
    else:
      print("❌ API 요청 실패:", response.status_code)
      break

  return all_patents

# 특허 포맷팅
def format_patents(patent_items):
  formatted = []
  for idx, item in enumerate(patent_items, start=1):
    application_number = item['applicationNumber']
    title = item['inventionTitle']
    register_status = item['registerStatus']
    abstract = item.get('astrtCont', '내용 없음')

    formatted.append(
        f"📌 번호: {idx}\n\n"
        f"📄 발명명: {title}\n"
        f"📌 출원번호: {application_number}\n\n"
        f"📌 특허내용: {abstract}\n\n"
        f"📌 특허등록상태: {register_status}\n"
        f"🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber={application_number}\n"
    )
  return "\n".join(formatted)

# 문장 임베딩
def get_embedding(text):
  response = client.embeddings.create(
      model="text-embedding-ada-002",
      input=text
  )
  return np.array(response.data[0].embedding)

# 코사인 유사도 계산
def cosine_similarity(vec1, vec2):
  return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# 사용자 질문과 유사 특허 찾기
def find_similar_patents(user_question, patents, top_n=5):
  user_emb = get_embedding(user_question)
  similarities = []

  for item in patents:
    title = item['inventionTitle']
    abstract = item.get('astrtCont', '내용 없음')
    text = title + " " + abstract
    patent_emb = get_embedding(text)

    similarity = cosine_similarity(user_emb, patent_emb)
    similarities.append((item, similarity))

  similarities.sort(key=lambda x: x[1], reverse=True)
  return similarities[:top_n]

# 유사 특허 포맷팅
def format_similar_patents(similarities):
  formatted = []
  for idx, (item, sim_score) in enumerate(similarities, start=1):
    application_number = item['applicationNumber']
    title = item['inventionTitle']
    register_status = item['registerStatus']
    url = f"https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber={application_number}"

    formatted.append(
        f"📌 번호: {idx}\n"
        f"📄 발명명: {title}\n"
        f"📌 출원번호: {application_number}\n"
        f"📋 유사도: {sim_score * 100:.2f}%\n"
        f"📌 특허등록상태: {register_status}\n"
        f"🔗 상세보기: {url}\n"
    )
  return "\n".join(formatted)

# 등록 가능성 및 차별화 포인트 분석
def assess_patentability_with_score(user_question, patents):
  prompt = f"""
당신은 특허 등록 가능성을 판별하는 AI입니다.

사용자 질문: "{user_question}"

다음은 검색된 유사 특허 목록입니다:

"""

  for idx, item in enumerate(patents, start=1):
    title = item['inventionTitle']
    abstract = item.get('astrtCont', '내용 없음')
    prompt += f"{idx}. 제목: {title}\n내용: {abstract}\n\n"

  prompt += """
요구사항:
- 등록 가능성(%)를 수치로 제시하세요.
- 차별화 포인트를 1~2개 추천하세요. (예: LLM 최적화, 새로운 데이터셋 활용 등)

출력 포맷 예시:
"등록 가능성: 75%
차별화 포인트: '특정 알고리즘 최적화', '응용 분야 확대'"
"""

  completion = client.chat.completions.create(
      model="gpt-4",
      messages=[
        {"role": "system", "content": "당신은 특허 심사관입니다."},
        {"role": "user", "content": prompt}
      ]
  )

  return completion.choices[0].message.content.strip()

# 메인 실행
if __name__ == "__main__":
  user_question = input("📝 사용자 질문을 입력하세요: ")

  # 1. 키워드 추출
  keywords_info = extract_keywords_from_question(user_question)
  print(f"🔎 추출된 키워드: {keywords_info}")

  all_patents = []

  # 2. 주요 키워드 검색
  for keyword in keywords_info.get("주요 키워드", []):
    patents = search_all_patents(keyword)
    if patents:
      all_patents.extend(patents)

  # 3. 보조 키워드 검색
  for keyword in keywords_info.get("보조 키워드", []):
    patents = search_all_patents(keyword)
    if patents:
      all_patents.extend(patents)

  # 4. 중복 제거
  seen = set()
  unique_patents = []
  for patent in all_patents:
    app_no = patent['applicationNumber']
    if app_no not in seen:
      seen.add(app_no)
      unique_patents.append(patent)

  # 5. 결과 출력
  if unique_patents:
    print("\n🤖 검색된 특허 목록:\n")
    formatted_output = format_patents(unique_patents)
    print(formatted_output)

    # 6. 유사 특허 찾기
    print("\n🧠 사용자 질문과 유사한 특허 Top 5:\n")
    similarities = find_similar_patents(user_question, unique_patents)
    similar_patents_output = format_similar_patents(similarities)
    print(similar_patents_output)

    # 7. 등록 가능성 평가 + 차별화 포인트 제시
    print("\n📈 등록 가능성 및 차별화 포인트 분석:\n")
    assessment = assess_patentability_with_score(user_question, [item for item, _ in similarities])
    print(assessment)

  else:
    print("❌ 관련 특허를 찾지 못했습니다.")
# Out:
# 🔎 추출된 키워드: {'주요 키워드': ['개인 맞춤형', '학습 경로 추천', '교육 플랫폼'], '보조 키워드': []}
#
# 🤖 검색된 특허 목록:
#
# 📌 번호: 1
#
# 📄 발명명: 개인맞춤형 약물치료관리 방법 및 이를 위한 시스템
# 📌 출원번호: 1020220182493
#
# 📌 특허내용: 본 발명은 개인맞춤형 약물치료관리 방법 및 이를 위한 시스템에 관한 것이다. 구체적으로 본 발명은 사용자의 의약품 및 약물치료에 대한 현황을 관리해 주는 주체로 약국 또는 약국서버를 활용함으로써 사용자의 개인맞춤형 약물치료관리 서비스를 제공하는 것에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220182493
#
# 📌 번호: 2
#
# 📄 발명명: 개인맞춤형 뇌 자극 시스템 및 이를 이용한 뇌 자극 방법
# 📌 출원번호: 1020230194662
#
# 📌 특허내용: 본 발명의 일 실시예에 따른 개인맞춤형 뇌 자극 시스템은, 단말; 및 상기 단말과 통신하는 뇌 자극 디바이스;를 포함하는 시스템에 있어서, 상기 단말에 설치된 애플리케이션을 통해, 사용자와 관련된 우울증의 증상과 정도를 평가하기 위한 벡 우울척도(Beck Depression Inventory, BDI) 정보 및 상기 우울증에 대한 민감성을 측정하는 라이덴 우울 감수성 지수(Leiden Index of Depression Sensitivity-Revised, LEIDS-R) 정보 중 적어도 하나인 제1 정보가 수집되고, 상기 단말은 상기 수집된 제1 정보를 상기 뇌 자극 디바이스로 전송하며, 상기 뇌 자극 디바이스는, 상기 수신한 제1 정보를 기초로, 우울증 관련 기설정된 복수의 상태 중 상기 사용자가 제1 상태에 해당하는 것으로 결정하는 제어부; 및 상기 사용자의 뇌의 복수의 영역에서 동기화된 진동을 동조시키기 위해, 상기 결정된 제1 상태에 따라 달라지는 자극을 상기 사용자의 뇌에 전달하는 자극부;를 포함하고, 상기 자극은, 상기 사용자의 뇌의 복수의 영역에서 동기화된 감마(gamma) 진동을 동조시키기 위한 제1 자극, 상기 사용자의 뇌의 복수의 영역에서 동기화된 델타(delta), 세타(theta), 알파(alpha) 및 베타(beta) 중 어느 하나의 진동을 동조시키기 위한 제2 자극 또는 ...(이하생략)
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230194662
#
# 📌 번호: 3
#
# 📄 발명명: 개인맞춤형 뇌 자극 디바이스
# 📌 출원번호: 1020230194661
#
# 📌 특허내용: 본 발명의 일 실시예에 따른 개인맞춤형 뇌 자극 디바이스는, 객체의 생체정보를 측정하는 센서부; 상기 센서부로부터 측정된 상기 객체의 생체정보를 기초로, 상기 객체의 상태가 우울증 관련 기설정된 복수의 상태 중 제1 상태에 해당하는 것으로 판단하는 제어부; 및 상기 객체의 뇌의 복수의 영역에서 동기화된 진동을 동조시키기 위해, 상기 제어부로부터 판단된 제1 상태에 따라 달라지는 자극을 상기 객체의 뇌에 전달하는 자극부;를 포함하고, 상기 자극은, 상기 뇌의 복수의 영역에서 동기화된 감마(gamma) 진동을 동조시키기 위한 제1 자극, 상기 뇌의 복수의 영역에서 동기화된 델타(delta), 세타(theta), 알파(alpha) 및 베타(beta) 중 어느 하나의 진동을 동조시키기 위한 제2 자극 또는 상기 제1 자극과 상기 제2 자극을 조합한 제3 자극이며, 상기 제1, 2, 3 자극은 경두개교류전기자극(tACS: transcranial Alternating Current Stimulation)이고, 상기 경두개교류전기자극은, 기설정된 제1 주파수에 따라 온(ON) / 오프(OFF)가 반복되고, 상기 제1 주파수에 따라 온(ON)된 신호가 기설정된 제2 주파수에 따라 자극으로 인가되도록 하는 제1 복합 자극(combined signal)일 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230194661
#
# 📌 번호: 4
#
# 📄 발명명: 개인맞춤형 생활체육 추천 플랫폼 시스템
# 📌 출원번호: 1020180166967
#
# 📌 특허내용: 본 발명의 일 실시예에 따른 개인맞춤형 생활체육 추천 플랫폼 시스템은 사용자 정보, 신체 정보, 관심 정보를 포함하는 개인 데이터를 제공하는 사용자 단말; 및 상기 개인 데이터를 수집하고, 복수의 공공 데이터를 연계 서버로부터 크롤링하며, 상기 개인 데이터와 공공 데이터를 기초로 미리 설정된 기계 학습 및 추천 알고리즘을 통하여 개인화된 맞춤형 생활 체육 종목과 지역 기반의 생활체육 시설 정보를 상기 사용자 단말로 제공하는 정보제공서버;를 포함한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020180166967
#
# 📌 번호: 5
#
# 📄 발명명: 사용자 개인 맞춤형 기반의 문진 데이터 추출 및 운영 시스템
# 📌 출원번호: 1020230050059
#
# 📌 특허내용: 본 발명은 사용자 개인 맞춤형 기반의 문진 데이터 추출 및 운영 시스템에 관한 것으로, 사용자의 건강 상태를 추적 관찰하기 위하여 사용자의 나이, 성별, 키, 체중, 질병정보를 포함하는 사용자 정보를 입력하여 가입하고, 수신된 건강 문진 데이터에 해당 여부를 입력한 후 제공하는 사용자 단말기;와, 상기 사용자 단말기를 통해 입력된 사용자 정보를 제공받아 회원으로 저장하기 위한 사용자 정보 수집부와, 상기 사용자 단말기로 제공될 건강 문진 데이터를 사용자 정보에 기반하여 생성 및 제공하는 문진 생성모듈;과, 상기 문진 생성모듈에서 생성하여 제공된 문진 데이터를 상기 사용자 단말기로부터 입력받아 수집하는 문진 수집모듈;과, 상기 문진 수집모듈을 통해 수집된 문진 데이터를 기반으로 상기 사용자의 예측 위험군 정보를 분류하고, 여기서 분류된 예측 위험군 정보를 기준으로 상기 사용자에게 제공될 문진 데이터를 상기 문진 생성모듈에서 생성되도록 결정하는 사용자 진단부;를 포함하여 구성되고, 상기 사용자로부터 수집된 문진 데이터를 저장하며 상기 문진 데이터를 기반으로 사용자의 건강 상태를 예측 진단하는 플랫폼 서버;를 포함하여 구성된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230050059
#
# 📌 번호: 6
#
# 📄 발명명: 암 면역요법을 위한 개인맞춤형 종양 백신 및 이의 용도
# 📌 출원번호: 1020227023239
#
# 📌 특허내용: 약독화된 암세포를 포함하는 개인맞춤형 종양 백신 및 상기 개인맞춤형 종양 백신을 사용하여 암을 치료하는 방법이 본원에 개시된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020227023239
#
# 📌 번호: 7
#
# 📄 발명명: 인공지능기반 개인맞춤형 인지 중재 방법
# 📌 출원번호: 1020190063030
#
# 📌 특허내용: 본 발명의 목적은, 사용자로부터 제공된 이미지로부터 상기 이미지와 관련된 일반정보 및 개인정보를 추출하며, 추출된 사진정보를 이용하여 치매환자를 치료하기 위한 다양한 인지중재도구들을 제공할 수 있는, 인공지능기반 개인맞춤형 인지 중재 시스템 및 그 방법을 제공하는 것이다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190063030
#
# 📌 번호: 8
#
# 📄 발명명: 개인 맞춤형 독서 튜터링 및 교육 콘텐츠 제공 시스템
# 📌 출원번호: 1020230128717
#
# 📌 특허내용: 개인 맞춤형 독서 튜터링 및 교육 콘텐츠 제공 시스템이 제공된다. 본 발명의 일 실시예에 따른 개인 맞춤형 독서 튜터링 및 교육 콘텐츠 제공 시스템은 사용자 프로필 데이터, 독서 이력 데이터, 독서 능력 데이터, 북 메타데이터, 피드백 데이터, 평가 데이터, 학습 경로 데이터, 상호작용 로그 데이터, 또는 콘텐츠 분석 데이터를 포함하는 사용자 메타데이터를 기초로 상기 사용자의 독서 지수 및 독서 난이도를 추론하는 독서능력 진단검사 모듈; 상기 메타데이터, 상기 독서 지수, 또는 상기 독서 난이도를 기초로 상기 사용자에 대한 독서 교육 컨설팅을 제공하는 독서 지도사 모듈; 독서교육 문항 데이터베이스와 콘텐츠 개발 표준 데이터를 기초로 상기 사용자에 대한 맞춤형 독서교육 문항을 생성하고, 상기 사용자에 대한 맞춤 도서 큐레이션을 제공하는 독서 교육문항 생성 모듈; 및 도서 PDF 파일로부터 텍스트 및 이미지를 추출하고, 상기 텍스트 및 상기 이미지를 이용하여 애니메이션 북을 생성하는 애니메이션 북 생성 모듈을 포함한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230128717
#
# 📌 번호: 9
#
# 📄 발명명: 임베디드 3D프린팅을 통해 영양소함량이 정밀 제어된 개인맞춤형 영양제조성물의 제조방법
# 📌 출원번호: 1020230012880
#
# 📌 특허내용: 본 발명은 사용자의 생체정보 및 식이활동정보에 기초하여 영양소요구량정보를 도출하고, 사용자에게 요구되는 영양소가 함유된 드롭렛를 포함하는 개인맞춤형 영양제조성물을 제공할 수 있는, 임베디드 3D프린팅을 통해 영양소함량이 정밀 제어된 개인맞춤형 영양제조성물의 제조방법에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230012880
#
# 📌 번호: 10
#
# 📄 발명명: 개인맞춤형 치아 모델링 방법
# 📌 출원번호: 1020170113979
#
# 📌 특허내용: 본 발명은 개인맞춤형 치아 모델링 방법에 관한 것으로서, 마련단계와, 제1획득단계와, 제2획득단계와, 제1생성단계와, 제2생성단계를 포함한다. 마련단계는 디지털화된 3차원 표준치아 모델을 마련한다. 제1획득단계는 환자 치아의 치관의 3차원 형상 데이터를 획득한다. 제2획득단계는 환자 치아의 2차원 단면 형상 데이터를 획득한다. 제1생성단계는 환자 치아의 치관의 3차원 형상 데이터와 표준치아 모델의 치근 부분을 결합하여 1차 환자 치아 모델을 생성한다. 제2생성단계는 환자 치아의 2차원 단면 형상 데이터 중 치근 부분의 형상과 같아지도록 1차 환자 치아 모델의 치근 부분을 수정하여 2차 환자 치아 모델을 생성한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020170113979
#
# 📌 번호: 11
#
# 📄 발명명: 개인 맞춤형 모닝콜 서비스 시스템 및 방법
# 📌 출원번호: 1020070083264
#
# 📌 특허내용: 본 발명은 개인 맞춤형 모닝콜 서비스 시스템 및 방법에 관한 것이다. 본 발명은 인터넷을 연결하기 위한 웹 서버; IPTV 모닝콜 서비스를 위해 각 모듈을 제어하는 제어부; 사용자 단말로부터 모닝콜 설정 정보를 수신받아 모닝콜 예약 시각 및 IPTV 모닝콜 서비스를 위해 개인 맞춤형 정보를 설정하는 모닝콜 예약 시각 및 개인 맞춤형 정보 설정부; 회원별로 모닝콜 예약 시각에 셋탑박스와 디지털 TV를 자동으로 ON 시키기 위한 WOL(Wake on LAN) 웨이크업 프레임을 사용자 단말로 전송하는 WOL 웨이크업 프레임 전송부; 회원별로 모닝콜 예약 시각에 기 설정된 개인 맞춤형 모닝콜 컨텐츠를 제공하기 위한 개인 맞춤형 모닝콜 컨텐츠 제공부를 포함하는 모닝콜 서비스 서버를 구비하고, 모닝콜 서비스 서버는 IPTV 모닝콜 서비스와 관련된 EPG 정보 또는 서비스 메뉴 정보를 멀티캐스트 방식으로 사용자 단말로 전송하기 위한 IPTV 헤드엔드 시스템과 연결된다. 이와 함께, 모닝콜 서비스 서버와 연동된 IPTV 서비스 시스템은 모닝콜 서비스와 관련된 EPG 또는 서비스 메뉴를 고속 인터넷망을 통해 다수의 사용자 단말로 전송하고, 모닝콜 예약 시각에 모닝콜 서비스 서버로부터 기 설정된 음악, 뮤직비디오, 개인 맞춤형 뉴스를 제공한다.  IPTV, 모닝콜, 음악, 개인 맞춤형 뉴스
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020070083264
#
# 📌 번호: 12
#
# 📄 발명명: 개인 맞춤형 토지 적정 매매가격을 산출하는 방법 및 장치
# 📌 출원번호: 1020220144546
#
# 📌 특허내용: 일 측면에 따른 개인 맞춤형 토지 적정 매매가격을 산출하는 방법은, 대상 토지에 대한 정보를 포함하는 제1 정보를 추출하는 단계; 상기 토지의 환경에 대한 정보를 포함하는 제2 정보를 추출하는 단계; 상기 토지에 관련된 사용자의 정보를 포함하는 개인 맞춤형 정보를 추출하는 단계; 및 상기 제1 정보, 상기 제2 정보 및 상기 개인 맞춤형 정보에 기초하여, 상기 토지에 대한 적정 매매가격을 산출하는 단계;를 포함한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220144546
#
# 📌 번호: 13
#
# 📄 발명명: 인공지능 기반 개인맞춤형 외국어시험용 학습 시스템
# 📌 출원번호: 1020210037700
#
# 📌 특허내용: 본 발명은 인공지능 기반 개인맞춤형 외국어시험용 학습 시스템에 관한 것으로서, 더욱 상세하게는 문제에 대한 답의 선택에 따라 제공되는 부가 문제 및 동영상 강의를 차별화시켜 학습자에게 제공하며, 오답 유형에 따른 개인 맞춤형 솔루션을 제공하여 학습자의 학습 수행 능력을 효율적으로 향상시킬 수 있는 인공지능 기반 개인맞춤형 외국어시험용 학습 시스템에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210037700
#
# 📌 번호: 14
#
# 📄 발명명: 딥러닝 기반의 3차원 의료영상 분석 및 의사결정 지원을 통한 개인맞춤형 임플란트 식립 가이드 제작을 위한 장치 및 방법
# 📌 출원번호: 1020230116236
#
# 📌 특허내용: 본 발명은 딥러닝 기반의 3차원 의료영상 분석 및 의사결정 지원을 통하여 임플란트 식립 위치를 자동으로 결정하고 정밀성을 높인 시술이 가능하도록 한 개인맞춤형 임플란트 식립 가이드 제작을 위한 장치 및 방법에 관한 것으로 분할 처리부에서 분할 처리되어 분류(Classification) 된 정보로부터 결측 치아의 영역 정보를 추출 및 인식하는 결측 영역 인식부;환자의 상하악 모델의 잔존치 치아 배열분석을 통한 교합평면 결정을 하여, 평균 모델과 교합 및 공간 분석을 통해 상실치의 최종 수복물의 위치와 외형을 결정하고, 임플란트 식립 안전영역(safe zone)을 결정하는 픽스쳐 식립 범위 분석부;상기 픽스쳐 식립 범위 분석부의 분석 결과를 기준으로 임플란트 경계 영역(bounding area)을 결정하고, 임플란트 경계 영역의 골질 및 골량을 분석하여 이를 기준으로 임플란트 픽스쳐 및 드릴링 시퀀스 결정을 하는 최적 식립 부위 분석부;치아 결측 부위 형태를 기준으로 임플란트 가이드의 형태를 학습시켜 자동으로 임플란트 가이드 설계값 산출하는 임플란트 가이드 설계값 산출부;를 포함하는 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230116236
#
# 📌 번호: 15
#
# 📄 발명명: 개인맞춤형 화장료 제안방법
# 📌 출원번호: 1020150045694
#
# 📌 특허내용: 본 발명은 측정 대상자의 피부의 가시광선 스펙트럼을 촬영하는 단계; 개인맞춤형 가시광선 스펙트럼을 상기 측정된 피부의 가시광선 스펙트럼과 매핑하여 스펙트럼 대조 테이블을 생성하는 단계; 상기 스펙트럼 대조 테이블과 개인맞춤형 조성물을 매칭하는 단계; 및 상기 매칭된 개인맞춤형 조성물을 화상부에 표시하는 단계를 포함하는 개인맞춤형 화장료 제안방법과, 이를 구현하는 시스템을 제공한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150045694
#
# 📌 번호: 16
#
# 📄 발명명: 신경망을 이용한 개인 맞춤형 헬스케어 서비스 장치 및 방법
# 📌 출원번호: 1020220015061
#
# 📌 특허내용: 본 발명은 사용자의 건강 상태에 맞도록 식품을 추천할 수 있는 신경망을 이용한 개인 맞춤형 헬스케어 서비스 장치에 대한 것으로, 보다 구체적으로는 사용자의 다양한 입력 데이터에 대응하여, 사용자에게 개인 맞춤형 상담을 제공하도록 상담 데이터를 생성하는 인공지능 상담 제공부, 인공지능 상담 제공부로부터 획득된 상담 데이터를 카테고리별 건강 방어 체계에 맞추어 추천 식품을 선별하여 사용자에게 추천할 추천 식품 데이터를 생성하는 건강 방어 체계 추천부, 추천 식품 데이터와 다양한 식품들의 생산자들의 구매가능한 식품을 매칭하여, 사용자에게 상기 추천 식품 중, 구매가능한 식품을 상기 사용자가 선택할 수 있는 구매가능 식품 제공부, 사용자가 상기 구매가능 식품 제공부를 통해 추천받은 구매가능한 식품을 온라인으로 구매할 수 있도록 하는 주문(order) 데이터를 생성하고 처리할 수 있는 주문 처리부를 포함하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220015061
#
# 📌 번호: 17
#
# 📄 발명명: 개인맞춤형 국소 적용 패치
# 📌 출원번호: 1020217021223
#
# 📌 특허내용: 개인맞춤형 국소 적용 패치는 복수의 분리된 영역을 갖는 패치 기재(substrate); 및 복수의 분리된 영역 중 적어도 하나에 배치된 하나 이상의 활성 효과제를 포함한다.
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020217021223
#
# 📌 번호: 18
#
# 📄 발명명: 운동능력 기반 개인맞춤형 영양제 제공시스템
# 📌 출원번호: 1020220170611
#
# 📌 특허내용: 본 발명은 개인맞춤형 영양제 제공 시스템에 관한 것으로서, 본 발명은 개인맞춤형 영양제 제공 시스템에 관한 것으로서, 사용자의 신체능력을 측정하는 복수의 측정방법을 저장한 측정방법 데이터 베이스와, 상기 측정방법에 따라 사용자가 측정한 측정값을 저장하는 신체능력 데이터 베이스와, 상기 측정된 신체능력 측정값을 사용자의 신체정보와 사용자의 건강정보에 맞추어 환산한 개인별 분석결과를 저장하는 분석결과 데이터베이스와, 복수의 구성 성분, 영양제 제품명, 적정 섭취정보를 포함한 영양제 정보가 저장되는 영양제 데이터베이스와, 사용자에게 신체능력 측정방법을 제공하고, 측정된 신체능력값을 기반으로 사용자의 신체정보와 사용자의 건강정보를 반영하여 사용자의 적정운동량과 적정 휴식량을 연산하고, 사용자의 신체정보와 상기 사용자의 적정운동량에 따라 사용자에게 필요한 영양제와 섭취 타이밍과 섭취량을 제공하는 제어부와, 신체능력 측정앱을 실행하고, 사용자의 신체정보를 입력하며, 영양제 정보를 수신하는 사용자 단말을 포함하여, 사용자의 나이나 건강상태 및 운동능력에 맞는 개인별 적정 운동량과, 신체활동별 운동량에 따른 최적의 영양제 정보를 제공받을 수 있고, 최적의 영양제 섭취 타이밍과 영양제의 섭취량을 제공받을 수 있으므로 종래의 일괄적인 영양제 섭취에 비하여 사용자에 맞춘 최적의 영양제 섭취방법을 제공받아 영양제 섭취의...(이하생략)
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220170611
#
# 📌 번호: 19
#
# 📄 발명명: 차량 내 운전자 개인맞춤형 졸음 위험도 판단 방법 및 시스템
# 📌 출원번호: 1020230042626
#
# 📌 특허내용: 차량 운전자의 상태를 실시간 모니터링하고, 졸음 방지 등의 안전 기능을 제공하려는 방법 및 시스템이 제공된다. 본 발명의 실시예에 따른 차량 내 운전자 개인맞춤형 졸음 위험도 판단 방법은, 차량 내 설치되는 카메라, 차량의 스티어링 휠에 마련되는 ECG(심전도) 센서 및 지문 센서 및 운전석 시트에 설치되는 차압 센서가 구비되는 센서부를 통해 데이터를 획득하는 단계; 프로세서가, 획득된 데이터를 기반으로 운전자 인증을 수행하는 단계; 운전자 인증이 정상적으로 수행되면, 프로세서가 획득된 데이터를 기반으로 운전자의 실시간 심박수, 호흡수 및 HRV(심박변이도)를 추정하는 단계; 및 운전자 인증이 정상적으로 수행되면, 프로세서가, 획득된 데이터를 기반으로 운전자의 졸음 위험도를 판단하는 단계;를 포함한다. 이에 의해, 개인인증 과정부터 생체신호 취득 과정까지 피부 습도 정도, 차량 내부의 밝기 등을 추정하여 가중치를 다르게 적용하여 각 상황에 맞게 개인인증 및 생체신호 취득 정확도를 높게 유지할 수 있다. 또한, 운전자의 졸음 상태를 탐지하여, 졸음운전 감지 시에 경보음 대신, 바이노럴 비트를 제공하여 졸음운전을 예방할 수 있다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230042626
#
# 📌 번호: 20
#
# 📄 발명명: 이온가교형 겔상비드를 포함하는 개인맞춤형 영양제조성물의 제조방법
# 📌 출원번호: 1020220180393
#
# 📌 특허내용: 본 발명은 사용자의 생체정보 및 식이활동정보에 기초하여 영양소요구량정보를 도출하고, 사용자에게 요구되는 영양소가 함유된 겔상비드를 포함하는 개인맞춤형 영양제조성물을 제공할 수 있는, 이온가교형 겔상비드를 포함하는 개인맞춤형 영양제조성물의 제조방법에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220180393
#
# 📌 번호: 21
#
# 📄 발명명: AI 기반의 개인맞춤형 사용자환경을 제공하는 화상회의방법
# 📌 출원번호: 1020210036815
#
# 📌 특허내용: 본 발명은 화상회의 프로그램(100)이 저장된 사용자 컴퓨터(10)는 인터넷을 이용하여 서버(20)에 접속하는 단계(S10); 상기 화상회의 프로그램(100)에 사용자가 입장하기 전 상기 화상회의 프로그램(100)은 대기실에서 사용자의 외모 및 배경을 편집할 수 있는 메뉴를 제공하는 단계(S20); 상기 사용자 컴퓨터(10)는 상기 대기실에서 편집이 완료된 사용자의 외모 및 배경을 저장하는 단계(S30); 상기 사용자는 상기 화상회의 프로그램(100)의 회의실에 입장하는 단계(S40); 및 상기 사용자 컴퓨터(10)는 화상회의 프로그램(100)에 상기 저장된 사용자의 외모 및 배경을 적용한 정보를 서버(20)에 전송하고, 상기 서버(20)는 상기 상기 저장된 사용자의 외모 및 배경을 적용한 정보를 상대방 컴퓨터(30)에 전송하는 단계(S50)를 포함하고, 상기 화상회의 프로그램(100)은 사용자가 접속시 사용자의 외모 및 배경을 편집할 수 있는 메뉴를 포함하는 대기실 모듈(110); 상기 대기실에서 사용자가 편집을 완료한 외모 및 배경을 저장할 수 있는 저장 모듈(120); 및 상기 사용자가 입장하여 상대방과 문자, 영상 및 음성 정보를 상호 교환하여 출력할 수 있는 회의실 모듈(130)을 포함하는 것을 특징으로 하는 AI 기반의 개인맞춤형 사용자환경을 제공하는 화상회의방법에 관한 것이다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210036815
#
# 📌 번호: 22
#
# 📄 발명명: 개인별 맞춤형 면역증진식품의 선별을 위한 면역분석방법
# 📌 출원번호: 1020110003907
#
# 📌 특허내용: 본 발명은 (a1) 피험자로부터 분리된 면역세포를 후보식품의 존재하에 배양하는 단계; 및 (b1) 상기 단계 (a1)에서의 배양결과 상기 후보식품이 면역세포를 활성화하는지를 결정하는 단계를 포함하는, 개인별 맞춤형 면역증진 식품의 선별을 위한 면역분석방법을 제공한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020110003907
#
# 📌 번호: 23
#
# 📄 발명명: 개인맞춤형 카페추천 시스템
# 📌 출원번호: 1020220164468
#
# 📌 특허내용: 본 발명에 따른 개인맞춤형 카페추천 시스템은 사용자 현재위치 기준 카페도착 예상소요시간에 따른 추천카페 리스트가 제공되도록 하거나, 세분화된 복수의 카페이용형태 카테고리, 세분화된 복수의 카페구비시설-영업정보 카테고리, 세분화된 복수의 카페대표특징 카테고리, 세분화된 복수의 카페대표메뉴 카테고리가 설정되어 사용자에게 제시되고, 사용자의 카테고리 선택에 따라 해당 카테고리와 연동된 추천카페 정보가 사용자 현재위치정보에 맞추어 제공되며, 카페추천 앱을 통해 작성되는 고객 후기 내에 포함된 키워드로부터 산출되는 후기기반선호도 수치값이나 사용자가 직접 입력하게 되는 직접입력 선호도 수치값이 각 카테고리 별로 부여되는 한편 사용자 개인취향이나 이용목적이 고려된 카테고리 별 가중치가 부여되면서 최종 산출되는 선호도 정량데이터가 각각의 카페 정보에 포함되는 구성을 제공함으로써 사용자는 개인 취향이나 개인 이용목적에 최적화된 카페를 간편하고 신속하게 추천받을 수 있게 된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220164468
#
# 📌 번호: 24
#
# 📄 발명명: 인공지능에 기반한 개인 맞춤형 건강관리 컨텐츠 제공 방법 및 시스템
# 📌 출원번호: 1020210194590
#
# 📌 특허내용: 본 발명은 송수신기능을 가진, 일상생활 측정장치, 생체정보 측정장치, 개인 휴대단말 등을 통해, 사용자의 일상생활 측정 정보, 생체 측정 정보, 문진 정보가 지속적이며 자동적으로, 메인서버로 전송되고, 이 정보들을 메인서버는 사용자별로 데이터 클러스터에 저장하여 빅데이터를 형성하고, 사용자별 빅데이터를 인공지능망에 적용하여 사용자의 증상발생 위험(질병 발생 위험) 정도와 증상을 예측하고, 증상예측 정보, 개인정보, 생활패턴정보를 분석하여 사용자의 건강을 유지/증진/치유하는 목적으로 제공되는 건강관리 컨텐츠의 형태(텍스트/사진/음향/영상 등)/제공시간 등을 고려하여 효과적으로 개인 맞춤 형태로 제공하는, 인공지능에 기반한 개인 맞춤형 건강관리 컨텐츠 제공 방법 및 시스템에 관한 것이다.  따라서, 본 발명의 인공지능에 기반한 개인 맞춤형 건강관리 컨텐츠 제공 방법 및 시스템은, 사용자로 하여금, 자신의 건강상태를 보다 효과적으로 자각하고, 경각심을 갖도록 만든다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210194590
#
# 📌 번호: 25
#
# 📄 발명명: 지문스캐너를 갖춘 셋탑박스를 이용한 인터넷 TV의 시청제한, 개인 맞춤형 광고 및 개인 맞춤형 프로그램 가이드 제공 방법 및 시스템
# 📌 출원번호: 1020090108467
#
# 📌 특허내용: 개인 맞춤형 프로그램 제공 방법 및 시스템을 제공한다. 개인 맞춤형 프로그램 제공 시스템은 지문스캐너를 갖춘 셋탑박스를 이용하여, 인터넷 TV의 시청제한, 개인맞춤 광고 또는 개인맞춤 프로그램 가이드를 제공할 수 있다. 이러한, 개인 맞춤형 프로그램 제공 시스템은 지문스캐너를 통해 지문을 스캔하여 사용자에 관한 식별정보를 식별하고, 상기 식별된 식별정보를 인터넷 TV 제공서버로 전송하는 셋탑박스, 상기 전송된 식별정보에 상응하는 개인맞춤 프로그램 가이드를 상기 셋탑박스로 전송하는 인터넷 TV 제공서버, 및 상기 전송된 개인맞춤 프로그램 가이드를 제공하는 인터넷 TV를 포함한다.  지문스캐너, 개인맞춤, 광고, 프로그램, 인터넷 TV
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020090108467
#
# 📌 번호: 26
#
# 📄 발명명: 재활 운동 처방이력 정보를 활용한 개인맞춤형 재활 운동 추천 방법 및 그 장치
# 📌 출원번호: 1020230007910
#
# 📌 특허내용: 재활 운동 처방이력 정보를 활용한 개인맞춤형 재활 운동 추천 방법이 개시된다. 이 방법은, 자원 저작부가, 재활 환자에게 처방되는 운동들과 상기 운동들의 진행 계획을 나타내는 운동 프로그램들을 저작하는 단계; 운동 추천 모듈이, 상기 저작된 운동들 중에서 사전 학습된 추천 모델을 이용하여 상기 재활 환자의 속성 정보에 적합한 운동들을 추천하는 단계; 및 운동 프로그램 추천 모듈이, 상기 저작된 운동 프로그램들 중에서 상기 추천된 운동들을 기반으로 상기 재활 환자의 속성 정보에 적합한 운동 프로그램을 추천하는 단계를 포함한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230007910
#
# 📌 번호: 27
#
# 📄 발명명: 개인맞춤형 레시피 추천 방법 및 이를 위한 연산장치
# 📌 출원번호: 1020220013187
#
# 📌 특허내용: 본 발명은 개인맞춤형 레시피를 추천하는 방법, 그리고 이를 위한 연산장치에 관한 것이다. 구체적으로는 학습이 가능한 알고리즘, 특히 벡터 임베딩을 수반하는 알고리즘을 활용하여 특정 사용자의 성향 및 다양한 상황에 맞는 개인맞춤형 레시피를 추천하는 방법 및 이를 위한 연산장치에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220013187
#
# 📌 번호: 28
#
# 📄 발명명: 환자건강개선을 위한 AI 기반 개인맞춤형 영양관리 서비스 제공 장치 및 방법
# 📌 출원번호: 1020230075584
#
# 📌 특허내용: 환자건강개선을 위한 AI 기반 개인맞춤형 영양관리 서비스 제공 장치 및 방법을 제공하기 위하여, 환자별 개인맞춤형 영양관리 서비스를 제공하는 장치에 있어서, 프로세서 및 상기 프로세서에 의해 실행 가능한 명령어들을 저장하는 메모리를 포함하고, 상기 프로세서는, 상기 명령어들을 실행함으로써, 미리 학습된 식사처방 스크리닝 모델을 이용하여 환자의 진료 기록 정보를 기초로 환자의 식이치료 필요 여부를 판단하고, 미리 학습된 영양처방 가이드 모델을 이용하여 환자의 진료 기록 정보 및 면담 정보를 기초로 환자에 대한 영양처방 정보를 산출하고, 미리 학습된 맞춤형 질병식 레시피 모델을 이용하여 상기 영양처방 정보 및 환자의 식습관 정보를 기초로 환자의 질병 및 식습관에 대응하는 영양성분 정보를 포함하는 환자 맞춤형 식단 및 레시피를 제공하는, 영양관리 서비스 제공 장치가 제공된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230075584
#
# 📌 번호: 29
#
# 📄 발명명: 개인 얼굴 맞춤형 피부관리 마스크장치 및 이를 이용한 피부 관리 방법
# 📌 출원번호: 1020150107147
#
# 📌 특허내용: 본 발명 개인얼굴 맞춤형 피부관리 마스크장치는 개인 얼굴 안면이 노출되도록 개구부가 형성되도록 얼굴 외곽 라인을 따라 대략 타원형으로 이루어지고, 내주면에 안면 외곽 피부와 밀착되는 실링부재 및 두상에 착용하기 위한 착용부재를 가진 마스크본체; 상기 마스크본체 일단부와 힌지 조립되어 회전 개폐되며, 상기 개구부를 폐쇄하는 외형을 이루면서 내측으로 공간부가 인입 형성되어 있고, 투명 또는 반투명 합성수지로 이루어진 보온커버; 상기 개인 얼굴의 안면 크기와 대응되게 이루어져 상기 보온커버 공간부에 장착되는 것으로, 상기 개인 얼굴의 눈에 대응하는 관통홀과 상기 얼굴의 콧구멍, 입에 대응하는 호흡통로가 형성되어 있고, 상기 보온커버가 회전하여 상기 개구부를 폐쇄하는 힘에 의해 그 내측면이 얼굴 외형을 따라 완충되게 소프트 한 쿠션층이 구비되어 상기 쿠션층의 외향 탄발력에 의해 상기 얼굴의 안면을 전체적으로 가압하는 탄성가압부재; 상기 개인 얼굴을 3D 스캐닝한 데이터를 기준으로 안면 형상에 대응되게 형성되면서 상기 눈과 상기 호흡통로에 대응되는 위치에 대응하여 관통되게 제작된 3D가압마스크;를 포함하는 것을 특징으로 한다. 따라서, 고객 자신의 얼굴의 꼭 맞는 개인 맞춤형 마스크를 제공하므로 개인 맞춤 마스크를 통해 외부에서 공급되는 온열, 냉각, 고주파, 저주파 등의 다양한 피부 관리 시술을 선택적 또...(이하생략)
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150107147
#
# 📌 번호: 30
#
# 📄 발명명: 산업용 개인맞춤형 귀마개용 필터
# 📌 출원번호: 1020180014876
#
# 📌 특허내용: 본 발명은 인간의 음성에 해당하는 주파수 대역에서는 음압 감쇄량이 작고, 산업현장에서 소음으로 느낄 수 있는 주파수 대역에서는 음압 감쇄량이 상대적으로 크도록 하여, 산업현장에서 작업자간 의사소통은 원활하면서도 기계장치 등의 소음은 줄여주는 산업용 개인맞춤형 귀마개용 필터에 관한 것이다.  이를 위해 본 발명은 양단이 개방되고 중공을 구비하며 일단에는 걸림턱이 구비되어 타단보다 내경이 작은 하우징; 하우징의 내부에 삽입되어 걸림턱에 안착되며 하우징 타단의 내경보다는 작고 하우징 일단의 내경보다는 큰 지름을 갖는 제1 플레이트; 하우징의 내부에 삽입되어 제1 플레이트와 접촉하되, 외경은 제1 플레이트의 지름보다 크고 내경은 제1 플레이트의 지름보다 작은 링 형상의 스페이서(spacer); 하우징의 내부에 삽입되어 스페이서와 접촉하되 제1 플레이트와 평행하도록 배치되고, 스페이서의 내경보다는 크고 스페이서의 외경보다는 작은 지름을 갖는 제2 플레이트; 하우징의 타단 개방부에 결합되며 일부는 폐쇄되고 일부는 개방된 개방부를 갖는 커버를 포함하는, 산업용 개인맞춤형 귀마개용 필터를 제공한다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020180014876
#
# 📌 번호: 31
#
# 📄 발명명: 개인맞춤형 기능성 식단 정보 및 비대면 서비스 제공 플랫폼 시스템
# 📌 출원번호: 1020210133286
#
# 📌 특허내용: 본 발명은 개인맞춤형 기능성 식단 정보 및 비대면 서비스 제공 플랫폼 시스템에 관한 것이다. 더욱 상세하게, 메타버스 기능이 연동되어, 식단 정보, 전문가 또는 인플루언서의 비대면 서비스 또는 컨텐츠를 맞춤형으로 매칭하여 제공할 수 있는 개인맞춤형 기능성 식단 정보 및 비대면 서비스 제공 플랫폼 시스템에 관한 것이다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210133286
#
# 📌 번호: 32
#
# 📄 발명명: 개인 맞춤형 온라인 가상 전시관 서비스 서버, 개인 맞춤형 온라인 가상 전시관 서비스 제어 방법, 개인맞춤형 온라인 가상 전시관 서비스를 제공하기 위한 프로그램이 저장된 컴퓨터로 판독 가능한 기록매체
# 📌 출원번호: 1020220134564
#
# 📌 특허내용: 본 발명은 온라인 상에서의 가상의 전시관을 제공하는 시스템에 관한 것으로, 더 상세하게는 3D,메타버스(Metaverse). 증강현실(AR), 가상현실(VR) 기술과 소셜 플랫폼(Social Platform)을 활용한 온라인 가상 전시관을 제공하도록 하되 사용자 개인정보를 기반으로 하여 개인 맞춤별 온라인 가상 전시관을 제공하는 개인 맞춤형 온라인 가상 전시관 서비스 서버, 개인 맞춤형 온라인 가상 전시관 서비스 제어 방법, 개인맞춤형 온라인 가상 전시관 서비스를 제공하기 위한 프로그램이 저장된 컴퓨터로 판독 가능한 기록매체에 관한 것이다.  본 발명에서는 개인의 성향은 물론, 인간의 감정에 영향을 줄 수 있는 장소, 날씨등 환경적 요인은 물론 전시물과 함께 제공될 음악이나, 전시관 배경 등의 정보를 제공할 수 있도록 하며, 또한 본 발명은 상기에서와 같이 개인 맞춤형으로 제공되는 전시물, 또는 전시물과 함께 제공되는 음악, 전시관 배경 등의 정보를 NFT(Non-Fungible Token)화하여 거래가 이루어질 수 있도록 한 개인 맞춤형 온라인 가상 전시관 제공 서버 및 그 서버 제어방법을 제공하고자 한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220134564
#
# 📌 번호: 33
#
# 📄 발명명: 대학의 통합적 성과 관리와 개인 맞춤형 학생 지원을 위한 적응적 빅데이터 분석 방법 및 시스템
# 📌 출원번호: 1020200027953
#
# 📌 특허내용: 본 발명은 대학 중장기발전계획과 각종 재정지원사업의 예・결산 및 성과를 연계시켜 관리할 수 있는 적응적인 데이터 모델 및 방법을 통해 대학의 성과를 상시적・종합적으로 관리할 수 있도록 하고, 학생패널 데이터에 대한 빅데이터 분석 모형 적용을 통한 맞춤형 학생지원 프로그램 개발과 대학 핵심성과지표 향상을 위한 정책을 개발할 수 있도록 하는 대학의 통합적 성과관리와 개인맞춤형 학생지원을 위한 적응적 빅데이터 분석 모델과 시스템에 관한 것이다. 이를 위해, 본 발명은 대학 운영계 DB, 문서파일, 인터넷/SNS 데이터 등으로 구성된 원천데이터 DB(110)로부터 데이터를 추출하고 변환하여 데이터마트 DB(140)에 적재하는 원천데이터 추출/변환/적재모듈(120)과, 데이터마트 DB(140)를 설계하는 데이터설계모듈(130)과, 데이터마트 DB(140)로부터 성과관리를 위한 각종 지표현황 분석결과를 담은 장표를 생성하는 장표생성모듈(150)과, 데이터마트 DB(140)의 데이터에 대해서 빅데이터 분석기법을 적용하여 의미 있는 분석결과를 도출하는 빅데이터분석모듈(160)과, 장표와 빅데이터 분석결과를 바탕으로 리포트를 자동 생성하는 리포트생성모듈(170)을 포함하는 것을 특징으로 하는 대학의 통합적 성과관리와 개인맞춤형 학생지원을 위한 적응적 빅데이터 분석 시스템을 제공한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020200027953
#
# 📌 번호: 34
#
# 📄 발명명: IP 기반의 방송 서비스에서의 개인맞춤형채널 관리장치
# 📌 출원번호: 1020070102135
#
# 📌 특허내용: IP 기반의 방송 서비스에서의 개인맞춤형채널 관리장치 및 방법이 개시된다. IP 기반의 방송 서비스에서의 개인맞춤형채널 관리장치 및 방법은 각 시청자가 편성한 방송 프로그램 편성 목록에 따라 방송 프로그램을 실시간으로 제공하는 개인맞춤형채널들로 구성된 시청그룹의 그룹관리자로부터 시청그룹에 속한 개인맞춤형채널 중에서 그룹관리자의 감시대상으로 선택된 감시채널의 정보를 포함하는 감시채널선택메시지를 수신하는 감시채널선택메시지수신부; 선택된 감시채널에서 실시간 제공되는 방송 프로그램을 그룹관리자에게 전송하는 감시채널제공부; 및 그룹관리자로부터 전송된 감시채널의 방송 프로그램이 유해하다는 유해판단메시지를 수신한 경우에는 감시채널의 방송 프로그램 제공을 강제종료시키는 유해채널차단부를 포함함으로써, 시청자에게 유해한 방송프로그램을 제공하는 채널을 차단하고, 미리 제공된 스케줄에 맞는 방송을 제공하도록 용이하게 관리할 수 있다.  IP 기반 방송, 개인맞춤형채널 서비스
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020070102135
#
# 📌 번호: 35
#
# 📄 발명명: 심미적인 스마일 형성을 위한 개인맞춤형 입술 견인기 제작 방법, 이에 따라 제작되는 개인맞춤형 입술 견인기 및 이를 수행하는 개인맞춤형 입술 견인기 제작 장치
# 📌 출원번호: 1020230022900
#
# 📌 특허내용: 본 발명은 심미적인 스마일 형성을 위한 개인맞춤형 입술 견인기를 제작하기 위한 개인맞춤형 입술 견인기 제작 방법에 관한 것으로, 수집부가 사용자의 안면 정보를 수집하는 단계; 분석부가 상기 안면 정보로부터 상기 사용자의 미소선을 검출하여 분석하는 단계; 설계부가 분석된 미소선에 기초하여 상기 사용자의 미소선 교정을 위한 개인맞춤형 입술 견인기의 형상을 설계하는 단계; 및 제작부가 설계된 형상에 따라 상기 개인맞춤형 입술 견인기를 제작하는 단계를 포함한다. 이에 의해 심미적인 스마일을 형성하기 위해서 관련 근육의 수축을 유도하는 훈련을 수행할 수 있는 입술 견인기를 제공하는 것은 물론, 개개인의 미소선을 분석하고, 미소선 분석 결과에 따라 사용자 개인에 맞는 입술선 모양으로 입술 견인기를 제작할 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230022900
#
# 📌 번호: 36
#
# 📄 발명명: 개인맞춤형 건강관리 포탈 시스템 및 그 구동방법
# 📌 출원번호: 1020120082366
#
# 📌 특허내용: 본 발명은 헬스케어 기술을 개시한다. 즉, 본 발명의 실시예에 따른 개인맞춤형 건강관리 포탈 시스템 및 그 구동방법은 다수의 운동종목과 각기 매칭되는 다수의 운동종목 앱 컨텐츠를 휴대용 통신 단말기 선택에 따라 다운받도록 하며, 다운로드된 운동종목 앱 컨텐츠의 초기 구동시점부터 종료시점까지 발생된 다양한 파라미터 값들을 사용자용 DB(Database)에 기록 저장하여 년월주일별로 정렬시킨 개인맞춤형 건강관리일지록 정보를 비롯해 적어도 하나의 맞춤형 광고 컨텐츠를 휴대용 통신 단말기에게 제공함으로써, 자신에게 맞는 운동활동시 운동종목 앱 컨텐츠를 매개로 자신이 성취시키고자 하는 건강목표를 이루기 위한 동기를 적극적으로 부여해 주고, 운동활동에 따른 체력관리 및 스캐줄 관리를 보다 체계적이면서 종합적으로 관리할 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020120082366
#
# 📌 번호: 37
#
# 📄 발명명: 개인 맞춤형 호흡 동기화를 위한 심박변이 기반의 청각자극 변조 장치 및 방법
# 📌 출원번호: 1020150006669
#
# 📌 특허내용: 본 발명은 사용자의 심장박동 간격 변이를 기반으로 진폭이 변조된 청각 자극을 제공하는 개인 맞춤형 호흡 동기화를 위한 심박변이 기반의 청각자극 변조 장치 및 방법에 관한 것으로,  본 발명에 따른 개인 맞춤형 호흡 동기화를 위한 심박변이 기반의 청각자극 변조 장치는, 사용자의 심전도 신호와 호흡 신호를 포함하는 생체 신호를 측정하는 생체 신호 측정부; 동기역학적 특성 분석 방법으로 상기 측정된 생체 신호를 분석하는 생체 신호 분석부; 상기 분석된 생체 신호를 기반으로 진폭이 변조된 청각 자극을 생성하는 청각자극 변조부를 포함하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150006669
#
# 📌 번호: 38
#
# 📄 발명명: 유전자 분석 데이터 및 생활습관 데이터 기반의 개인 맞춤형 헬스케어 시스템
# 📌 출원번호: 1020200032281
#
# 📌 특허내용: 일 양상에 유전자 분석 데이터 및 생활습관 데이터 기반의 개인 맞춤형 헬스케어 시스템 및 이를 컴퓨터에서 실행시키기 위한 프로그램을 기록한 컴퓨터로 읽을 수 있는 기록 매체에 의하면, 명확한 기준을 바탕으로 개인 맞춤형 헬스케어 정보를 제공할 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020200032281
#
# 📌 번호: 39
#
# 📄 발명명: 개인 맞춤형 AI 풋케어 마사지기
# 📌 출원번호: 1020240073563
#
# 📌 특허내용: 본 발명은 개인 맞춤형 AI 풋케어 마사지기로서, 사용자 단말로부터 입력되는 PGHD를 측정하고, 측정된 PGHD를 인공지능으로 분석하여 솔루션을 제공하는 솔루션 서버;를 포함할 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020240073563
#
# 📌 번호: 40
#
# 📄 발명명: 개인맞춤형 임플란트 식립 가이드 제작을 위한 장치 및 방법
# 📌 출원번호: 1020190018746
#
# 📌 특허내용: 본 발명은 딥러닝 기반의 3차원 의료영상 분석 및 의사결정 지원을 통하여 임플란트 식립 위치를 자동으로 결정하고 정밀성을 높인 시술이 가능하도록 한 개인맞춤형 임플란트 식립 가이드 제작을 위한 장치 및 방법에 관한 것으로, 영상 획득 수단으로부터 제공되는 악골, 치아, 신경관이 라벨링된 3차원 이미지를 딥러닝 네트워크로 학습하여 분할(segmetnation)하는 분할 처리부;상기 분할 처리부에서 분할 처리되어 분류(Classification) 된 정보로부터 결측 치아의 영역 정보를 추출 및 인식하는 결측 영역 인식부;환자의 상하악 모델의 잔존치 치아 배열 분석을 통한 교합평면 결정을 하여, 평균 모델과 교합 및 공간 분석을 통해 상실치의 최종 수복물의 위치와 외형 결정하고, 임플란트 식립 안전영역(safe zone)을 결정하는 픽스쳐 식립 범위 분석부;상기 픽스쳐 식립 범위 분석부의 분석 결과를 기준으로 임플란트 경계 영역(bounding area)을 결정하고, 임플란트 경계 영역의 골질 및 골량을 분석하여 이를 기준으로 임플란트 픽스쳐 및 드릴링 시퀀스 결정을 하는 최적 식립 부위 분석부;치아 결측 부위 형태를 기준으로 임플란트 가이드의 형태를 학습시켜 자동으로 임플란트 가이드 설계값 산출하는 임플란트 가이드 설계값 산출부;를 포함하는 것이다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190018746
#
# 📌 번호: 41
#
# 📄 발명명: 개인화된 생체신호/주변환경 데이터에 기반한 개인맞춤형 활력징후정보 제공 방법 및 개인맞춤형 생활활력징후 제공 시스템
# 📌 출원번호: 1020180140575
#
# 📌 특허내용: 본 발명은 개인 생체신호 및 주변환경의 데이터를 연계시켜 활력징후를 실시간 신뢰성 있고 정확하며 신속하게 분석 판단하고, 활력징후 이상 판단 시 사용자 본인에게 알리며, 응급 시에는 연계 지인과 응급구조기관에 위치기반정보와 함께 알림할 수 있는 개인화된 생체신호/주변환경 데이터에 기반한 개인맞춤형 활력징후정보 제공 방법 및 개인맞춤형 생활활력징후 제공 시스템에 관한 것이다. 본 발명에 따르면, 사용자의 활력징후를 검출하여 소정 형식의 정보로 제공하기 위한 방법으로서, 활력징후를 판단하기 위한 데이터 인자(data factor)를 검출하는 데이터인자 검출 단계; 상기 검출된 데이터 인자 중 이상징후 데이터로서 불필요한 데이터를 필터링하는 데이터 필터링 단계; 상기 필터링된 데이터에 기반하여 활력징후에 이상 여부가 발생하였는지를 판단하는 이상징후 판단 단계; 및 상기 이상징후 판단 단계에서의 판단 결과에 기초하여 사용자 알림 또는 연계 알림할지 결정하는 알림 결정 단계;를 포함하는 것을 특징으로 하는 생체신호/주변환경 데이터에 기반한 개인맞춤형 활력징후정보 제공 방법이 제공된다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020180140575
#
# 📌 번호: 42
#
# 📄 발명명: 개인 맞춤형 운동지도 및 학습지도 서비스 제공방법
# 📌 출원번호: 1020090107565
#
# 📌 특허내용: 본 발명은 개인맞춤형 운동지도 및 학습지도 서비스 제공방법에 관한 것으로, 해결하고자 하는 기술적 과제는 헬스클럽 또는 학원 등에 설치된 체질진단기기를 이용하여 체질맞춤형 운동방법 및 학습방법 등의 서비스를 제공하는데 있다.  이를 위해 본 발명에 따른 개인맞춤형 운동지도 서비스 제공방법은, 헬스클럽에 설치된 체질진단기기를 이용하여 사용자의 체질 및 건강상태를 측정하는 체질 및 건강상태 측정단계와, 상기 체질진단기기를 통한 측정치에 의해 상기 사용자의 체질 및 건강상태를 진단하는 체질 및 건강상태 진단단계와, 진단된 상기 사용자의 체질 및 건강상태에 따라 맞춤형 운동방법을 지도하는 개인 맞춤형 운동지도 단계 및 진단된 상기 사용자의 체질 및 건강상태에 관한 정보를 상기 헬스클럽 홈페이지와 연동되는 온라인 서버에 송신하는 단계를 포함하는 것을 특징으로 하는 개인 맞춤형 운동지도 서비스 제공방법을 개시한다.  체질진단, 학습지도, 운동지도, 건강지수
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020090107565
#
# 📌 번호: 43
#
# 📄 발명명: 강화학습 기반 개인맞춤형 바이오피드백 시스템 및 방법
# 📌 출원번호: 1020210171573
#
# 📌 특허내용: 강화학습 기반 개인맞춤형 바이오피드백 시스템 및 방법이 개시된다. 본 발명의 일실시예에 따른, 강화학습 기반 개인맞춤형 바이오피드백 시스템은, 인체로부터 생체신호를 측정하고, 상기 측정된 생체신호에 따른 인체상태를 판단하는 생체신호 측정부; 강화학습 모델을 통해, 상기 인체상태에 기초한 체외 자극 명령을 학습하는 강화학습 처리부; 및 상기 체외 자극 명령에 따라 자극 종류, 자극 강도, 자극 시간에 관한 자극 형태를 결정 함으로써, 상기 인체에 부착되는 전극에서, 상기 결정된 자극 형태에 맞는 자극이 발생하도록 하는 체외 자극부를 포함할 수 있다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210171573
#
# 📌 번호: 44
#
# 📄 발명명: 응시자들의 그룹핑을 통한 개인맞춤형 모의고사 채점 및 문제 분석 시스템 및 그 방법
# 📌 출원번호: 1020150094545
#
# 📌 특허내용: 본 발명은 모의고사 채점 및 문제 분석 시스템 및 그 방법에 관한 것으로, 보다 상세하게는 모의고사를 응시한 응시자에게 각 문제마다의 정답률과 오답률을 보여주고 해당 응시자가 틀린 문제를 함께 틀린 다른 응시자들이 다른 시험에서는 어떠한 문제들을 틀리고 있는지를 보여줌으로써 학습능률을 향상시킬 수 있는 응시자들의 그룹핑을 통한 개인맞춤형 모의고사 채점 및 분석 시스템 및 그 방법에 관한 것이다.  본 발명에 따른 모의고사 채점 및 분석시스템은 복수 개의 시험세트들을 저장하고 있는 시험세트 데이터베이스; 상기 시험세트들의 시험 응시자에 대한 정보를 저장하고 있는 응시자 데이터베이스; 상기 시험세트들 중 어느 하나의 시험세트를 선택하여 모의고사를 출제하는 시험출제부; 상기 선택된 시험세트의 모의고사에 대한 상기 응시자들의 채점을 수행하는 시험채점부; 상기 시험채점부의 채점 결과를 이용하여 상기 선택된 시험세트의 각 문제에 대한 정답률과 오답률을 계산하는 정오답률 계산부; 상기 정오답률 계산부에서 계산된 각 문제에 대한 정답률과 오답률에 대한 정보를 각 응시자의 디스플레이장치에 보여주는 정오답률정보출력부;를 포함하고, 상기 정오답률 계산부는 상기 선택된 시험세트의 시험 응시자들을 상기 시험채점부의 채점에 따른 시험점수에 따라 복수의 그룹으로 그룹핑하는 응시자 그룹핑 모듈; 및 상기 복수의 그룹별 응시자들...(이하생략)
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150094545
#
# 📌 번호: 45
#
# 📄 발명명: 체형에 따라 하중분산과 운동성 조작이 가능한 개인 맞춤형 보행보조기
# 📌 출원번호: 1020130012611
#
# 📌 특허내용: 본 발명은 노약자용 보행보조기에 관한 것으로서, 주행을 위한 바퀴를 장착한 하부프레임; 상기 하부프레임 상방에 구비되는 상부프레임을 포함하는 노약자용 보행보조기에 있어서; 상기 상부프레임과 하부프레임은 서로 분리 가능하게 조립되며; 상기 상부프레임에는 각도조절이 가능하게 힌지 고정되는 핸들부와, 사용자의 하박을 거치할 수 있는 하박거치대가 더 구비된 것을 특징으로 하는 체형에 따라 하중분산과 운동성 조작이 가능한 개인 맞춤형 보행보조기를 제공한다.  이에 따라 체형에 따른 맞춤형 하중분산이 가능해지며, 핸들부와 하박거치대의 상하 위치 변동이 가능해지고 각각의 각도를 조절할 수 있게 되며, 핸들부와 하박거치대의 간격 폭 조절이 가능해져서 사용자 신체와 보조보행기 사이의 이격거리 조절이 용이해져서, 사용자의 신체적 특성과 이에 따른 보행습관에 알맞게 보조보행기를 조절할 수 있어 보행보조기를 컨트롤하는 제어능력과 운동성조절능력을 향상시키며, 손목과 하박의 각도를 체형에 맞추어 조절할 수 있게 됨으로써 운동성의 조절과 함께 체형에 따른 신체의 밸런스를 이루도록 하여 더욱 편안하고 힘이 적게 들며 덜 피곤한 편안한 이동이 가능하게 된다.  따라서, 본 발명에 의한 보조보행기는 손쉬운 조작에 의하여 다양한 사용자에게 개인맞춤형과 같은 기능을 보다 저렴한 비용으로 제공할 수 있게 된다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020130012611
#
# 📌 번호: 46
#
# 📄 발명명: 음성 정보 기반의 개인맞춤형 정신건강 분석 및 관리서비스 제공방법
# 📌 출원번호: 1020210024550
#
# 📌 특허내용: 음성 정보 기반의 개인맞춤형 정신건강 분석 및 관리서비스 제공방법이 개시된다.
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210024550
#
# 📌 번호: 47
#
# 📄 발명명: 사용자 정서상태에 따른 개인 맞춤형 심리테라피 추천 방법, 장치 및 컴퓨터 프로그램
# 📌 출원번호: 1020220105248
#
# 📌 특허내용: 컴퓨팅 장치에 의하여 수행되는 방법에 있어서, 사용자의 정서상태 정보를 획득하는 단계 및 상기 사용자의 정서상태에 대응하는 심리테라피 콘텐츠를 추천하는 단계를 포함하는, 사용자 정서상태에 따른 개인 맞춤형 심리테라피 추천 방법이 개시된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220105248
#
# 📌 번호: 48
#
# 📄 발명명: 방송 표준을 위한 개인 맞춤형 UX/UI서비스를 제공하는 장치 및 방법
# 📌 출원번호: 1020170166167
#
# 📌 특허내용: 본 발명의 일 실시예에 따른, UX/UI 서비스를 제공하는 방법에 있어서, (a) 사용자 단말로부터 사용자의 개인정보 및 과제 해결 능력 검사의 결과를 수신하고, 개인정보 및 상기 과제 해결 능력 검사의 결과를 종합 데이터베이스에 저장하는 단계; (b) 종합 데이터베이스를 토대로 사용자가 선호하는 서비스의 패턴을 분석하는 단계; 및 (c) 서비스의 패턴을 바탕으로 개인 맞춤형 서비스를 제공하는 단계;를 포함하는, 방송 표준을 위한 개인 맞춤형 UX/UI 서비스를 제공하는 방법이다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020170166167
#
# 📌 번호: 49
#
# 📄 발명명: 개인 맞춤형 무릎 관절 재활운동장치
# 📌 출원번호: 1020190131950
#
# 📌 특허내용: 본 발명은 개인 맞춤형 무릎 관절 재활운동장치에 관한 것으로, 베이스프레임(110)에 일측 종단이 회동가능하도록 구비되는 대퇴부 지지대(120a)(120b)와 상기 대퇴부 지지대(120a)(120b)와 회전가능하도록 결합되는 종아리 지지대(130a)(130b)가 복수개의 링크(140)로 연결되고 상기 링크(140)는 베이스프레임(110)에 구비된 왕복이동수단(150)에 의하여 왕복직선운동하여 대퇴부 지지대(120a)(120b)와 종아리 지지대(130a)(130b)를 소정각도로 접었다 펴기를 반복하는 무릎 관절 재활운동수단(100); 상기 대퇴부 지지대와 종아리 지지대의 연결부(156) 또는 왕복이동수단(150)에 구비되어 관절가동범위 즉, 대퇴부 지지대와 종아리 지지대간 각도를 검출하는 관절가동범위 검출수단(170); 사용자의 신체에 직접 부착되는 생체신호를 이용하거나, 사용자의 신체영상 또는 사용자의 음향신호를 기준으로 관절가동범위별 통증발생여부를 검출하는 통증발생 검출수단(180); 각종 데이터가 입력되고 출력되는 스마트 단말기(190); 상기 스마트 단말기(190)와 복수개의 검출수단(170)(180)으로부터 전송되는 신호를 기준으로 왕복이동수단(150)의 동작을 제어하는 제어부(200);를 포함하여 구성되는 개인 맞춤형 무릎 관절 재활운동장치를 통하여 최적의 재활운동효과를 얻을 수 있도록 하...(이하생략)
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190131950
#
# 📌 번호: 50
#
# 📄 발명명: 개인 정보분석을 통한 개인 맞춤형 플랫폼 서비스 시스템을 이용한 개인맞춤형 힐링시스템
# 📌 출원번호: 1020220078677
#
# 📌 특허내용: 본 발명은 개인 정보 분석을 통한 개인 맞춤형 플랫폼 서비스 시스템을 이용한 개인 맞춤형 힐링 시스템에 관한 것으로, 개인 맞춤형 플랫폼 서비스 시스템은 하나 이상의 휴대폰 단말기(1,...,1-N)와, 하나 이상의 개인 PC 단말기(2,...,2-N)이 유무선통신망을 통해 개인 맞춤형 플랫폼 서비스컴퓨터(서버)(10-1)에 접속하여 이루어지고, 상기 하나 이상의 휴대폰 단말기(1,...,1-N)와, 하나 이상의 개인 PC 단말기(2,...,2-N)에는 개인 맞춤형 플랫폼서비스가 제공하는 개인 맞춤형 플랫폼 서비스앱이 구비되며, 상기 개인 맞춤형 플랫폼 서비스 컴퓨터(서버)(10-1)에는 개인 맞춤형 플랫폼 서비스 프로그램이 내장되어 있고, 상기 개인 맞춤형 플랫폼 서비스컴퓨터(서버)는 개인 맞춤형 서비스 프로그램을 통해 사용자 단말로 부터 입력된 설문과 취향 선택 및 입력된 개인 정보와, 오감측정 신호를 통해 개인 맞춤형 플랫폼 서비스 프로그램을 가동하여 개인정보 통합 분석 결과값에 대응하는 진단분석결과를 제공하여 개인 맞춤형 처방을 제공하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220078677
#
# 📌 번호: 51
#
# 📄 발명명: 개인 정보분석을 통한 개인 맞춤형 플랫폼 서비스 시스템을 이용한 컬러돔 적용 개인맞춤형 힐링시스템
# 📌 출원번호: 1020220078678
#
# 📌 특허내용: 본 발명은 개인 정보 분석을 통한 개인 맞춤형 플랫폼 서비스 시스템을 이용한 컬러돔 적용 개인 맞춤형 힐링 시스템에 관한 것으로, 개인 맞춤형 플랫폼 서비스 시스템은 하나 이상의 휴대폰 단말기(1,...,1-N)와, 하나 이상의 개인 PC 단말기(2,...,2-N)이 유무선통신망을 통해 개인 맞춤형 플랫폼 서비스컴퓨터(서버)(10-1)에 접속하여 이루어지고, 상기 하나 이상의 휴대폰 단말기(1,...,1-N)와, 하나 이상의 개인 PC 단말기(2,...,2-N)에는 개인 맞춤형 플랫폼서비스가 제공하는 개인 맞춤형 플랫폼 서비스앱이 구비되며, 상기 개인 맞춤형 플랫폼 서비스 컴퓨터(서버)(10-1)에는 개인 맞춤형 플랫폼 서비스 프로그램이 내장되어 있고, 상기 개인 맞춤형 플랫폼 서비스컴퓨터(서버)는 개인 맞춤형 서비스 프로그램을 통해 사용자 단말로 부터 입력된 설문과 취향 선택 및 입력된 개인 정보와, 오감측정 신호를 통해 개인 맞춤형 플랫폼 서비스 프로그램을 가동하여 개인정보 통합 분석 결과값에 대응하는 진단분석결과를 제공하되, 개인정보 분석을 통해 맞춤형 컬러가 선택된 개인에 맞는 컬러 투명필름이 커버된 컬러 피라미드를 구비하여 개인 힐링이 가능하도록 한 것을 특징으로 한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220078678
#
# 📌 번호: 52
#
# 📄 발명명: 아토피피부염 환자 개인맞춤형 증상 관리 시스템
# 📌 출원번호: 1020220170799
#
# 📌 특허내용: 본 발명은 아토피피부염 환자 개인맞춤형 증상 관리 시스템에 관한 것으로, 본 발명에 따른 증상관리 시스템은 개인별 생물학적 특성, 행동 특성 또는 환경적 영향 특성을 종합적으로 고려하여 아토피피부염에 대한 개인별 증상관리 지침을 제공할 수 있는 것으로, 대상에 따라 최적화된 아토피피부염에 대한 관리 지침을 제공할 수 있다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220170799
#
# 📌 번호: 53
#
# 📄 발명명: 비콘을 이용한 개인맞춤형 음식관리시스템
# 📌 출원번호: 1020160000797
#
# 📌 특허내용: 본 발명은 음식점에 설치된 비콘정보를 확인하여 클라이언트 사용자에게 기피식재료가 포함된 요리를 실시간으로 제공할 수 있는 비콘을 이용한 개인맞춤형 음식관리시스템에 관한 것이다.  본 발명은 음식점에 설치된 비콘으로부터 비콘정보가 수신되면 음식관리서버(100)에게 제공하며, 음식관리서버(100)로부터 기피식재료가 사용된 요리에 대한 기피요리 알림정보를 수신받아 표시하는 클라이언트(200)와; 음식점에서 판매되는 식재료가 기재된 요리정보와 음식점에 설치된 비콘정보를 등록하는 음식점 단말기(300)와; 사용자의 기피식재료에 대한 정보가 등록되고, 음식점에서 판매되는 식재료가 기재된 요리정보와 음식점에 설치된 비콘정보가 등록되며, 클라이언트(200)로부터 비콘정보가 수신되면 비콘정보에 매칭된 음식점의 요리정보로 기재된 식재료가 사용자의 기피식재료와 일치되면 기피요리 알림정보를 클라이언트(200)에게 제공하는 음식관리서버(100);를 포함하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020160000797
#
# 📌 번호: 54
#
# 📄 발명명: 인공지능 기반 개인맞춤형 영양 밸런스화된 간편식의 조리 및 콜드체인배송 시스템
# 📌 출원번호: 1020210049277
#
# 📌 특허내용: 본 발명의 인공지능 기반 개인맞춤형 간편식 조리 및 콜드체인 배송 서비스 제공방법은 음식 리스트를 수요자 단말로 제공하는 단계와, 수요자 단말로부터 수요자 건강정보를 수집하는 단계와, 제공된 음식 리스트로부터 선택된 수요자 선택 음식을 취득하는 단계와, 영양점수 학습 블록을 통해, 수집된 수요자 건강정보에 기초하여 수요자 선택 음식의 영양점수를 스코어링하는 단계와, 스코어링된 수요자 선택 음식의 영양점수가 영양기준치 미달인지 여부를 판정하는 단계와, 수요자 선택 음식의 영양점수가 영양기준치 미달인 경우, 건강정보 빅데이터, 영양정보 빅데이터 및 식품별 영양정보에 기초하여 적어도 하나의 후보레시피를 산출하는 단계와, 적어도 하나의 후보레시피, 수요자 선택 음식의 영양점수, 적어도 하나의 후보레시피에 따라 조리된 적어도 하나의 영양밸런스 음식의 영양점수를 수요자 단말로 제공하는 단계와, 수요자 선택 음식과 적어도 하나의 영양밸런스 음식 중 수요자 단말을 통해 선택된 최종 주문 음식을 수집하는 단계와, 최종 주문 음식 및 최종 주문 음식에 대한 선택레시피를 조리사 단말로 제공하는 단계와, 선택레시피에 기초하여 패키징 방식 및 배달조건을 산출하는 단계를 포함한다.
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210049277
#
# 📌 번호: 55
#
# 📄 발명명: 개인맞춤형 건강관리시스템
# 📌 출원번호: 1020210032962
#
# 📌 특허내용: 본 발명의 개인맞춤형 건강관리시스템은 사용자단말 및 전문가단말과 통신하고, 사용자 정보를 수집 및 가공하여 건강관련 서비스를 제공하는 서버, 건강서비스 관련 클라이언트 프로그램을 실행하여 사용자의 개인정보 및 건강정보를 포함하는 사용자 정보를 제공하고 건강관련 서비스를 요청하는 사용자단말 및 건강서비스 관련 클라이언트 프로그램을 실행하여 상기 사용자의 건강을 판정하고 맞춤형 피드백을 제공하는 전문가단말을 포함한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210032962
#
# 📌 번호: 56
#
# 📄 발명명: AI 기반 개인맞춤형 트레이너 매칭 방법
# 📌 출원번호: 1020220129904
#
# 📌 특허내용: 본 발명은 AI 기반 개인맞춤형 트레이너 매칭 방법에 관한 것으로서, 성별, 체중 및 검색 키워드 중 적어도 어느 하나 이상을 포함하는 사용자의 정보를 획득하는 정보 획득 단계; 상기 사용자의 정보 중에서 성별에 기초하여 사용자를 분류하는 1차 분류 단계; 상기 1차 분류 단계를 거쳐 분류된 상기 사용자를 체중정보에 기초하여 분류하는 2차 분류 단계; 및 상기 2차 분류 단계를 거쳐 분류된 상기 사용자에게 적합한 운동 트레이너를 추천하는 트레이너 추천 단계; 를 포함하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220129904
#
# 📌 번호: 57
#
# 📄 발명명: 개인 유전형 및 표현형 정보를 고려한 맞춤형 식품정보 추천 시스템
# 📌 출원번호: 1020150156844
#
# 📌 특허내용: 본 개시는 개인 유전형 및 표현형 정보를 고려한 맞춤형 식품정보 추천 시스템에 있어서, 유전형 정보, 표현형 정보, 사용자 식단 정보 중 적어도 하나 이상을 포함하는 사용자의 개인정보가 입력되는 입력부; 전장 유전체 연관 분석 (GWAS:genom wide association study) 정보 및 음식 정보가 저장된 저장부; 입력된 유전형 정보와 전장 유전체 연관 분석 정보를 이용하여 유전형 정보에 따른 비만 위험도를 계산하고, 표현형 정보와 음식 정보를 이용하여 적어도 하나의 식단 정보를 만드는 처리부; 그리고, 처리부에서 계산된 비만 위험도 및 처리부에서 만든 식단정보 중 적어도 하나 이상을 표시하는 표시부;를 포함하는 것을 특징으로 하는 개인 유전형 및 표현형 정보를 고려한 맞춤형 식품정보 추천 시스템에 관한 것이다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150156844
#
# 📌 번호: 58
#
# 📄 발명명: 개인맞춤형 에너지 측정 치유 시스템
# 📌 출원번호: 1020220019550
#
# 📌 특허내용: 개인맞춤형 에너지 측정 치유 시스템 및 방법이 제공된다. 개인맞춤형 에너지 측정 치유 방법은 저장된 기준 측정 주파수 목록을 구형파로 변환하고 인체에 인가하여 인체로부터 출력되는 미세 전기 신호를 생체 고유 에너지로서 측정하는 단계; 미세 전기 신호에서 잡음을 제거하고, 미세 전기 신호의 특징을 추출하여 정규화 과정을 수행하는 단계; 정규화된 미세 전기 신호로로부터 진단에 필요한 특징을 자동으로 선택하고 사영하여 다차원 데이터의 차원을 축소하여 새로운 차원의 데이터 세트를 생성하는 단계; 새로운 차원의 데이터 세트를 진단용 주파수 목록으로 변환하고 저장된 기준 주파수 목록의 편차를 분석하여 진단 결과로서 인체에 대한 건강 에너지 상태를 파악하는 단계; AI를 이용하여 에너지의 항진과 저하를 분류하고 산출된 정보로 에너지 항진 시 나타나는 인체의 항진 반응, 증상 및 질환과 에너지 저하 시 나타나는 저하 반응, 증상 및 질환으로 구분하고 다수의 세부 목록들에 대하여 우선 순위를 정하여 인체 각 조직의 정상적인 상관 관계를 고려하여, 인체 특성에 맞춘 양자 주파수를 조합하는 단계; 및 조합된 양자 주파수에 따라 항진 또는 저하되어 있는 에너지를 치료용 구형파로 변환하여 인체로 전사하는 개인용맞춤형 치료 프로그램을 제공하여 인체의 에너지를 보충하여 치료하는 단계를 포함한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220019550
#
# 📌 번호: 59
#
# 📄 발명명: 무선충전 기반의 개인맞춤형 스마트 TV 제공 방법 및 이를 위한 컴퓨터로 판독가능한 기록매체
# 📌 출원번호: 1020130056938
#
# 📌 특허내용: 본 발명은 무선충전 기반으로 개인맞춤형 스마트 TV 서비스를 제공하는 기술에 관한 것이다. 더욱 상세하게는 본 발명은 셋톱박스에 무선충전 모듈과 근거리 무선통신 모듈(예: 블루투스, NFC)을 구비하여 사용자가 자신의 스마트폰을 충전하기 위해 셋톱박스 위에 놓아두면 이를 자동으로 검출하여 셋톱박스와 스마트폰 양단에서 어플리케이션을 구동하고 근거리 무선통신을 통해 양단의 어플리케이션이 상호 통신함으로써 셋톱박스의 동작을 스마트폰 사용자에게 최적으로 맞춘 개인맞춤형 스마트 TV 서비스를 제공하는 기술에 관한 것이다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020130056938
#
# 📌 번호: 60
#
# 📄 발명명: 3D 프린팅 기술을 이용한 개인 맞춤형 저주파 보조기 및 제작방법
# 📌 출원번호: 1020220028912
#
# 📌 특허내용: 3D프린팅 기술을 이용한 개인 맞춤형 저주파 보조기 제작 방법에 있어서, 3D스캐너를 이용하여 사용자의 적어도 하나의 신체 부위의 형상 정보를 측정하는 단계, 제작기기에서 3D스캐너를 통해 상기 사용자의 적어도 하나의 신체 부위의 형상 정보를 수신하는 단계, 상기 제작기기가, 수신된 상기 적어도 하나의 신체 부위의 형상 정보에 기초하여, 3D 그래픽 설계하여 생성된 3D 프린팅 파일을 3D프린터로 전송하는 단계를 포함할 수 있다.  상기 3D프린팅 기술을 이용한 개인 맞춤형 저주파 보조기 제작 방법에 의해 제작된 개인 맞춤형 저주파 보조기는, 진동 자극기가 결합되는 체결부를 포함하며, 상기 체결부를 통해 진동 자극기와 결합된 보조기를 사용자가 착용할 경우, 사용자의 신체 일부에 진동 자극을 가할 수 있는 것을 특징으로 할 수 있다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220028912
#
# 📌 번호: 61
#
# 📄 발명명: 개인 맞춤형 자동화 식단 제공방법
# 📌 출원번호: 1020190006991
#
# 📌 특허내용: 본 발명은 이용자의 성별, 나이, 체중, 신장, 대사성 질환 유무 및 유전적 특성에 따른 대사성 질환 위험군 정보, 알레르기 유무 및 알레르기 관련 특정 식자재에 대한 정보와 이용자가 선택한 식단의 접근성, 식사종류 등을 기초로 하여 추출된 개인 맞춤형 식단 제공방법에 관한 것이다.  상기와 같은 본 발명에 따르면, 이용자는 전문서적을 참고하거나 전문가의 상담을 받기 위해 지불하여야 하는 과도한 시간과 비용의 소모를 절감할 수 있을 뿐만 아니라 건강증진이나 질병개선의 효과를 증대시킬 수 있는 효과가 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190006991
#
# 📌 번호: 62
#
# 📄 발명명: 개인 맞춤형 정보 제공 방법 및 그 장치
# 📌 출원번호: 1020150046189
#
# 📌 특허내용: 개인 맞춤형 정보 제공 방법 및 그 장치가 개시된다. 개인 맞춤형 정보 제공 장치는 사용자가 온라인에 등록한 게시글과 사용자와 관련 있는 온라인 그룹의 게시글을 수집한 후, 수집한 게시글의 카테고리별 빈도를 기초로 사용자에게 제공할 콘텐츠의 관심분야를 파악한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020150046189
#
# 📌 번호: 63
#
# 📄 발명명: 개인맞춤형 커피주문시스템 및 그 방법
# 📌 출원번호: 1020100110949
#
# 📌 특허내용: 본 발명은 제1사용자단말기로부터 커피제조 주문정보 및 위치정보를 수신하는 단계, 위치정보를 이용하여 제1사용자 단말기로 인근의 커피판매점들 정보를 전달하는 단계, 제1사용자 단말기로부터 사용자에 의해 선택된 커피판매점에 대한 선택 신호를 수신하는 단계, 제2사용자 단말기로 사용자 단말기정보를 전송하는 단계 및 커피판매점에 설치된 수신단말기로 커피제조 주문정보 및 사용자 단말기정보를 전달하는 단계를 포함하는 개인맞춤형 커피주문 방법을 제공한다.  따라서, 개인이 원하는 커피를 직접 조합하여 커피를 개인 맞춤형으로 주문할 수 있어 사용자의 선택의 폭을 확대할 수 있으며, 커피판매점에 도착하기 전에 외부에서 미리 주문할 수 있기 때문에 커피판매점에서 기다리는데 소요되는 시간을 줄일 수 있어 편의성을 향상시킬 수 있다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020100110949
#
# 📌 번호: 64
#
# 📄 발명명: 온라인 개인맞춤형 안경 추천도우미 시스템 및 그 방법
# 📌 출원번호: 1020210027780
#
# 📌 특허내용: [기술분야/해결과제]  본 발명은 온라인 개인맞춤형 안경 추천도우미 시스템 및 그 방법에 관한 것으로, 고객 또는 판매자가 단말기(스마트폰, 컴퓨터 등)를 통해 고객의 성별, 나이별, 제품(안경, 선글라스, 고글, 콘택트렌즈) 및 제품의 종류를 입력하고 고객의 얼굴을 촬영하여 입력하면, 고객의 얼굴에 어울리는 제품(안경, 선글라스, 고글, 콘택트렌즈)을 자동으로 추천받을 수 있고, 고객의 얼굴사진에 추천받은 제품의 이미지사진을 합성하여 제품이 어울리는지를 확인할 수 있고, 장바구니에 담거나 구매 및 결제할 수 있는 온라인 개인맞춤형 안경 추천도우미 시스템 및 그 방법에 관한 것이다.  [해결수단]  본 발명에 의한 온라인 개인맞춤형 안경 추천도우미 방법은, 고객의 성별, 나이별, 얼굴 모양과 크기에 맞는 제품(안경, 선글라스, 고글, 콘택트렌즈)을 추천해주는 온라인 개인맞춤형 안경 추천도우미 방법에 있어서, (a) 고객 또는 판매자 단말기(110,120)에 설치된 안경 추천도우미 프로그램(130)의 화면을 통해, 고객의 성별, 나이별, 제품과 제품의 종류를 입력받은 데이터 정보와 고객의 얼굴을 촬영한 얼굴사진(221)을 통신망을 통해 DB 서버(300)로 전송하는 단계; (b) 상기 DB 서버(300)에서 상기 고객 또는 판매자 단말기(110,120)로부터 수신받은 상기 데이터 정보와 고객의 얼굴사...(이하생략)
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210027780
#
# 📌 번호: 65
#
# 📄 발명명: 치아주위근육 정상 중립대 형성을 위한 개인 맞춤형 맹출유도와 골격교정용 마우스피스 및 그 제조방법
# 📌 출원번호: 1020180164600
#
# 📌 특허내용: 본 발명은 치아주위근육 정상 중립대 형성을 위한 개인 맞춤형 맹출유도와 골격교정용 마우스피스 및 그 제조방법에 관한 것이다.  본 발명은 이를 위해 (1) 3차원 CT 상에서 치아 배열과 구조 및 턱 등의 골격 위치 및 형태를 확인하는 단계; (2) 치아의 크기 측정 및 입안으로 맹출될 치아의 가장 긴 폭경을 기준으로 치아를 배열하는 단계 및 이상적인 영구치열 완성단계; (3) 상악과 하악을 이상적인 오버젯(overjet), 오버바이트(overbite)에 위치시킨 상태를 기준으로 프리웨이 스페이스(freeway space)를 두께로 하도록 상,하악 치아를 교합에 맞춰 이상적으로 배열하는 단계 또는 골격 이상이 있을 경우 하악과 상악의 변화가능 하게 환자가 움직일 수 있는 정도로 상하악을 위치시켜 점차적으로 정상적인 프리웨이 스페이스(freeway space) 두께가 되도록 배열하는 단계 ; (4) (3)단계에서 찾은 이상적 배열을 커버하는 맹출유도 마우스피스인 스플린트(splint)의 디자인을 결정하는 단계; 및 (5) 유치열은 치아 맹출속도에 맞춰, 영구치는 영구치열 대로 인체무해재료로 3D 프린팅 하는 단계; (6) 환자가 사용하고 영구치 맹출 속도에 맞게 수정 및 골격이상 영구치열 환자의 골격변화정도에 맞춰 다음 단계 장치 프린팅하여 적용하는 단계가 포함된다.  상기와 같이 구성된 본 발명은 ...(이하생략)
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020180164600
#
# 📌 번호: 66
#
# 📄 발명명: 개인맞춤형 재난정보 제공 방법 및 시스템
# 📌 출원번호: 1020200000717
#
# 📌 특허내용: 본 발명은 종래의 재난정보를 이동통신망을 통해 개인에게 전달함에 있어서 개인의 관심사를 고려하지 않고 일방적이고 동일한 재난정보로 전달함으로써 국민들이 재난정보에 무관심해짐으로써 효과적으로 재난에 대응할 수 없었던 한계점을 극복하기 위한 것으로, 기본 재난정보에 개인맞춤형 관심지역의 실제 상황 정보를 포함하여 재생성 후 전달하는 방법 및 그에 따른 장치이다. 본 발명에서는 다양한 개인들의 관심에 부합하는 재난정보를 생성하기 위해서 평상시에 미리 개인의 관심지역에 대한 정보를 수집하여 관리하고, 관심 지역에 설치된 다양한 계측기 및 센서 정보를 함께 수집, 분석 관리하는 방법을 제시한다. 위급 또는 긴급한 재난이 발생 또는 예측되어 재난정보가 제공될 때, 개인 관심지역에서 수집된 정보를 기본 재난정보와 결합하여 사용자 맞춤형 재난정보를 전달한다. 이를 통해 국민들의 재난정보에 대한 관심 및 신뢰도를 증가시키고 재난 발생시 신속하고 안전하게 대비 및 대응할 수 있도록 지원함으로써 인적, 물적, 경제적 피해를 최소화하는 효과가 예측된다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020200000717
#
# 📌 번호: 67
#
# 📄 발명명: 개인맞춤형 자율실행 무릎치료기 및 이의 동작 방법
# 📌 출원번호: 1020210068637
#
# 📌 특허내용: 본 개시 내용은 개인맞춤형 자율실행 무릎치료기 및 이의 동작 방법을 제시한다. 상기 무릎치료기는, 상기 무릎치료기를 착용한 사용자의 생체 정보를 획득하도록 구성되는 센서부; 발열 기능을 수행하도록 구성되는 발열부; 및 상기 생체 정보에 기초하여 상기 발열부의 동작 온도 및 동작 시간을 제어하도록 구성되는 제어부를 포함할 수 있다. 상기 제어부는 상기 생체 정보의 측정치가 제 1 조건을 만족하면 상기 발열부의 동작 온도를 미리 결정된 값만큼 증가시키고 상기 발열부의 동작 시간을 미리 결정된 값만큼 증가시키며, 상기 생체 정보의 측정치가 제 2 조건을 만족하면 상기 발열부의 동작 온도를 미리 결정된 값만큼 감소시키고 상기 발열부의 동작 시간을 미리 결정된 값만큼 감소시키며, 상기 생체 정보의 측정치가 위험 조건을 만족하면 사용자 단말기로 위험 상태 알림을 전송하도록 구성될 수 있다. 또한, 상기 제어부는 상기 무릎치료기의 사용 패턴 및 만족도에 기초하여 치료 패턴을 결정하고, 상기 치료 패턴에 따라 무릎치료기가 자율실행되게 할 수 있다.  본 개시 내용에 따르면, 사용자의 생체 정보 및 학습 기능에 기초하여 결정된 치료 패턴에 따라 수동 조작없이도 증상을 호전시키도록 자율동작할 수 있는 무릎치료기를 제공할 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210068637
#
# 📌 번호: 68
#
# 📄 발명명: 개인진료기록데이터베이스와 대응진료데이터베이스를 이용한 개인맞춤형 진료서비스 제공시스템 및 방법
# 📌 출원번호: 1020160141613
#
# 📌 특허내용: 개인진료기록데이터베이스와 대응진료데이터베이스를 이용한 개인맞춤형 진료서비스 제공시스템 및 방법이 개시된다. 본 발명은, 개인정보 및 개인의 진료기록을 저장하는 상기 개인진료기록 데이터베이스, 진료대상자의 조건에 따른 권장진료항목을 저장하는 상기 대응진료데이터베이스, 상기 대응진료데이터베이스로부터 추출한 권장진료항목을 저장하는 개인질병예방 데이터베이스, 및 통신네트워크를 통해 수신된 가입자 기본정보 및 진료기록을 상기 개인진료기록데이터베이스에 저장하고, 상기 개인진료기록데이터베이스로부터 추출한 조건 데이터와 상기 대응진료데이터베이스로부터 상기 권장진료항목을 추출하여 상기 개인질병예방데이터베이스에 저장시키는 사용자 단말기를 구비한다.
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020160141613
#
# 📌 번호: 69
#
# 📄 발명명: BLT요법에 근거한 인공지능 활용 개인맞춤형 영양제 추천 시스템
# 📌 출원번호: 1020210101961
#
# 📌 특허내용: 본 발명은 BLT요법에 근거한 인공지능 활용 개인맞춤형 영양제 추천 시스템에 관한 것으로서, 사용자별 특성에 따른 문진정보를 평가한 정보인 평가정보와 영양제에 대한 정보인 영양제정보가 축적되어 빅데이터가 구축되고, 인공지능 모델이 저장되는 데이터베이스부; 및 상기 문진정보를 평가하여 상기 평가정보를 생성하고, 상기 빅데이터를 통해 상기 평가정보에 매칭되는 상기 영양제정보가 각각 도출되도록 상기 인공지능 모델을 반복 학습시키고, 상기 문진정보가 입력되는 경우 학습된 상기 인공지능 모델을 이용하여 영양제 추천 결과를 도출하는 제어부를 포함한다.  본 발명에 따르면, 사용자는 자신의 체질, 건강상태 등의 특성에 가장 적합한 영양제를 추천받을 수 있다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210101961
#
# 📌 번호: 70
#
# 📄 발명명: 개인 맞춤형 치아 임플란트 조립체 및 이의 제조방법
# 📌 출원번호: 1020210179719
#
# 📌 특허내용: 본 발명은 체결이 편리하면서도 결합공차를 줄여 세균 및 이물질의 침투를 방지하면서도 쉽게 풀리지 않는 견고한 결합상태를 유지할 수 있는 개인 맞춤형 치아 임플란트 조립체 및 이의 제조방법을 개시한다. 본 발명은 내측에 일측 회전방향으로 제1 암나사산이 형성된 픽스쳐; 내측에 상기 일측 회전방향과 반대방향인 타측 회전방향으로 제2 암나사산이 형성된 어버트먼트; 상기 어버트먼트의 중공부에 삽입되어 상기 픽스쳐의 상기 제1 암나사산에 결합될 수 있도록 제1 수나사산이 형성된 제1 고정 볼트; 및 상기 어버트먼트의 상기 중공부에 삽입되어 상기 어버트먼트의 상기 제 2암나사산에 결합될 수 있도록 제2 수나사산이 형성되고, 내측에 드라이버 홀이 형성되고 내부는 관통되지 않는 제2 고정 볼트를 포함하고, 상기 제2 고정 볼트의 하단측에는 일정 높이로 돌출형성된 절두된 원뿔형상의 돌출부가 형성되고, 상기 제1 고정볼트의 상단은 상기 제2 고정 볼트의 상기 절두된 원뿔형상의 돌출부에 상보된 형상을 갖는 씰링 홈부가 형성된 것을 특징으로 한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210179719
#
# 📌 번호: 71
#
# 📄 발명명: 개인맞춤형 경품정보 제공시스템
# 📌 출원번호: 1020120054398
#
# 📌 특허내용: 본 발명은 고객의 생활패턴에 따른 맞춤형 경품정보를 제공함으로써 경품이벤트에 대한 고객의 만족도를 높이고 광고효과를 극대화할 수 있는 개인맞춤형 경품정보 제공시스템에 관한 것이다.  본 발명에 따르면, 인터넷이나 무선통신망을 통해 접속가능하며 경품정보DB(120)와 고객정보DB(140)를 포함하는 경품정보제공서버(100)와, 경품이벤트시행서버(200)와, 고객단말기(300)를 포함하는 경품정보 제공시스템에 있어서, 경품정보DB(120)에는 경품 시행업체명, 업종, 브랜드명, 판매상품, 행사명, 참여방법, 과제내용, 응모기간, 등록일, 발표일 및 시상품을 포함하는 이벤트정보(122)와, 타겟고객의 성별, 연령, 지역, 결혼여부, 가족사항, 직업 및 취미를 포함하는 타겟고객정보(124)를 포함하고, 고객정보DB(140)에는 가입한 고객의 성명, 성별, 연령, 주소, 결혼여부, 직업, 취미, 관심업체명, 관심브랜드명, 관심업종 및 관심상품을 포함하여 이루어지며, 고객이 고객단말기(300)를 통해 경품정보제공서버(100)에 접속하여 개인정보를 입력하고 경품이벤트정보를 조회하면, 경품정보제공서버(100)는 경품정보DB(100)의 이벤트정보(122)와 타겟고객정보(124)가 고객정보DB(140)의 데이터와 매칭되는 경품이벤트에 대하여 우선적으로 디스플레이한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020120054398
#
# 📌 번호: 72
#
# 📄 발명명: 개인 맞춤형 자동화 식단 제공방법
# 📌 출원번호: 1020160176901
#
# 📌 특허내용: 본 발명은 이용자의 성별, 나이, 체중, 신장, 대사성 질환 유무 및 유전적 특성에 따른 대사성 질환 위험군 정보, 알레르기 유무 및 알레르기 관련 특정 식자재에 대한 정보와 이용자가 선택한 식단의 접근성, 식사종류 등을 기초로 하여 추출된 개인 맞춤형 식단 제공방법에 관한 것이다.  상기와 같은 본 발명에 따르면, 이용자는 전문서적을 참고하거나 전문가의 상담을 받기 위해 지불하여야 하는 과도한 시간과 비용의 소모를 절감할 수 있을 뿐만 아니라 건강증진이나 질병개선의 효과를 증대시킬 수 있는 효과가 있다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020160176901
#
# 📌 번호: 73
#
# 📄 발명명: 국소피부제제 및 개인맞춤형 피부치료방법
# 📌 출원번호: 1020147026226
#
# 📌 특허내용: 섬유아세포의 배양으로부터 채취된 조정배지를 포함한 개인맞춤형 피부-고유의 국소제제가 개발되어왔다. 다른 국소제제와 다르게, 본 발명의 제제는 수용자-피부유형에 고유하고, 조정배지는 희망하는 피부특성을 가진 피시험체로부터 채취된다. 예를 들어, 아프리카계 미국인 피부는 백인 피부보다 적게 그리고 늦게 주름지는 것으로 알려져 있기 때문에, 조정배지는 창백한 피부에 적용하기 위하여 아프리카계 미국인 피부로부터 채취될 수 있다. 또 다른 구체예에서, 상기 섬유아세포는 노인피부에 투여하기 위해 젊은 피부로부터 채취될 수 있다. 또 다른 구체예에서, 여드름이나 변색이 되는 피부에 적용하기 위하여, 상기 섬유아세포는 여드름 또는 변색으로부터 고통받지 않는 피부로부터 채취될 수 있다. 피부 공여자 선택기준의 예시는 지연된 주름, 작은모공, 햇빛에 대한 저항성, 여드름에 대한 저항성, 균일한 착색 또는 얼룩짐 또는 나이반점의 부족 및 좋은 보습 유지력을 포함한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020147026226
#
# 📌 번호: 74
#
# 📄 발명명: 개인맞춤형 시력 교정 방법
# 📌 출원번호: 1020037003719
#
# 📌 특허내용: 본 발명은 눈의 피교정인에세 시력 교정을 제공하는 방법 및 비즈니스 아키텍쳐에 관한 것으로서, 웨이브프론트 수차 측정 정보 및, 옵션으로는, 환자 이력 데이터, 주문 데이터, 지출 데이터, 요금 청구 데이터 및 기타의 데이터를 피교정인으로부터 획득하는 단계와, 상기 다양한 데이터를 개개의 적절한 플랫폼에 전송, 예컨대, 웨이브프론트 수차 정보를 개인맞춤형 렌즈 공급 플랫폼에 전송하는 단계와, 피교정인에게 맞는 개인맞춤형 렌즈를 생성하는 단계와, 개인맞춤형 렌즈를 피교정인에게 개인적으로 배달하는 단계를 포함한다. 이 방법은 레이저 제거, 선삭 가공, 주형/성형 및 머시닝에 의한 콘택트 렌즈, 안구내 렌즈(IOL), 인레이 또는 온레이의 현장 렌즈 성형 가공 및 개인맞춤형 제조를 포함하는 맞춤 처리와 측정 처리를 더 포함한다. 본 발명에 의한 비즈니스 아키텍쳐는 시각 교정 방법의 단계를 채권적 수익 발생 비즈니스 거래들로 분리하는 것을 포함한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020037003719
#
# 📌 번호: 75
#
# 📄 발명명: 개인맞춤형 커피주문 경매시스템을 이용한 주문방법
# 📌 출원번호: 1020190010139
#
# 📌 특허내용: 본 발명은, 사용자단말기, 중앙서버, 커피판매점 단말기를 포함하는 개인맞춤형 커피주문 경매 시스템에 있어서,  상기 사용자 단말기는, 상기 중앙서버에 접속하여 사용자의 선택에 따른 블렌딩과 관련한 원두추출정보, 원두추출액에 첨가되는 첨가물정보 및 부가정보 중 선택된 적어도 어느 하나를 포함하는 커피제조 주문정보 및 위치정보를 전송하고, 상기 중앙서버로부터 인근 커피판매점들 정보를 수신하여 이를 표시하는 단계;  상기 인근커피판매점들 중 사용자에 의해 선택된 어느 하나의 커피판매점에 대한 선택신호를 상기 중앙서버로 전송한 후에 상기 중앙서버로부터 사용자 단말기정보를 수신하여, 개인맞춤형 커피주문 경매시스템에 송신하는 단계;  상기 송신된 커피제조 주문 정보에 동일하거나 유사한 커피제조가 가능한 근접한 위치의 타 커피 판매점의 단말기로 사용자의 주문정보를 발신하여 상기 주문한 커피제조에 대한 경매정보를 표시하고, 타 커피 판매점에서 입력한 가격정보를 사용자의 단말에 비교 표시한 후, 사용자의 최종 주문 및 결제를 기다리는 단계;  상기 사용자가 최종적으로 결제를 진행하면, 상기 중앙서버는, 상기 사용자단말기로부터 상기 커피제조 주문정보 및 위치정보를 수신하여 선택된 커피판매점의 커피제조장치로 상기 커피제조 주문정보를 전송하고 결제에 관한 정보를 커피 판매점 단말기에 전송하는 단계,  상기 커피판매점 단...(이하생략)
#
# 📌 특허등록상태: 취하
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190010139
#
# 📌 번호: 76
#
# 📄 발명명: 개인맞춤형 방진 마스크 및 개인맞춤형 방진 마스크 제작방법
# 📌 출원번호: 1020190058705
#
# 📌 특허내용: 개인맞춤형 방진 마스크 및 개인맞춤형 방진 마스크 제작방법이 개시된다. 개시된 개인맞춤형 방진마스크는 PMMA(Poly Methyl Methancrylate)로 이루어진 열가소성 수지를 사출성형하여 제조되며, 눈, 코, 입을 포함하는 얼굴전면을 감싸도록 돔형태로 이루어지며 패킹부재가 끼움결합되도록 링형의 끼움홈이 내면 테두리에 형성된 마스크본체; 얼굴면과 밀착되어 상기 마스크본체와 얼굴면의 밀폐성을 향상시키도록 상기 마스크본체의 내면에 형성된 상기 끼움홈에 결합되는 끼움돌기를 구비한 패킹부재를 포함하며, 상기 마스크본체에 상기 패킹부재가 결합된 상태에서, 상기 마스크본체를 유리전이온도까지 가열하여 연화시킨 다음, 연화된 상기 마스크본체 테두리부분을 얼굴면으로 가압하여 상기 마스크본체의 테두리부분이 사용자 얼굴면의 굴곡라인에 대응되게 형태변형되게 성형함으로써, 상기 패킹부재가 사용자의 얼굴면의 굴곡라인에 대응되는 형태를 갖도록 구성되어 얼굴면과의 밀착성이 향상되는 것을 특징으로 한다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190058705
#
# 📌 번호: 77
#
# 📄 발명명: 개인 취향에 맞는 맞춤형 커피 제공시스템 및 맞춤형 커피 제공방법
# 📌 출원번호: 1020190097544
#
# 📌 특허내용: 본 발명은 개인 맞춤형 커피 제공시스템에 있어서, 개인의 취향에 맞는 향미의 커피를 선택하기 용이하도록 커피에 대한 전문적인 지식이 아닌 시각적으로도 맛이 연상될 수 있는 익숙한 신맛, 단맛, 쓴맛의 형태로 향미정보를 제공하고 이를 선택하여 조합함으로써 커피의 향미를 선택할 수 있도록 안내하는 커피향미선택부(10)와, 개인이 선택한 커피의 향미정보를 통해 항상 일정한 향미를 갖는 커피를 선택할 수 있도록 커피향미선택부(10)에 의해 제공된 향미정보를 통해 선택한 개인 취향의 향미정보를 개인별로 저장하는 향미정보서버(20)와, 향미정보서버(20)에 저장된 개인 취향의 커피 향미를 제공하기 위해 다수의 커피원두를 소정의 비율로 혼합함으로써 선택된 향미의 커피를 제조하기 위한 커피제조방법을 통해 개인 맞춤형 향미정보에 맞는 커피를 제조하여 사용자에게 제공하는 커피제공부(30)로 구성되어 개인의 취향에 맞는 커피를 쉽게 선택할 수 있도록 커피원두의 맛이 아닌 개인이 쉽게 선택할 수 있는 일반적인 맛으로 가이드라인을 제공해줌으로써 자신이 선호하는 풍미의 커피를 미리 선택하고 이를 커피매장에 제시하여 항상 일정한 향미를 갖는 커피를 마실 수 있는 효과가 있으며, 개인의 취향에 맞게 선택된 커피정보를 저장하고 이를 이용하여 커피 매장에서 항상 동일한 향미를 갖는 커피를 제공받을 수 있는 효과가 있다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190097544
#
# 📌 번호: 78
#
# 📄 발명명: 개인 맞춤형 물리계층 사용으로 안전하게 보호되는 통신 및 제어 기술
# 📌 출원번호: 1020190117220
#
# ...
#
# 📌 번호: 291
#
# 📄 발명명: 통합 의복 디자인 교육 및 유통 플랫폼
# 📌 출원번호: 1020220098694
#
# 📌 특허내용: 본 발명은 의복 디자인 교육을 실시하고, 동시에 교육을 통해 형성한 디자인 제품을 제작 및 유통을 구현하는 플랫폼 구조에 대한 것으로, 온라인을통해서 디자인 교육콘텐츠를 제공하고, 이를 통해 디자인 교육을 용이하게 접근할 수 있도록 하며, 이를 기반으로 제작된 디자인 결과물의 검수, 확인, 보완을 수행할 수 있으며, 동시에 의복 제품의 제작 및 유통을 구현할 수 있는 통합프로그램을 제공할 수 있게 된다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220098694
#
# 📌 번호: 292
#
# 📄 발명명: 가상현실 기반의 통합 교육 서비스 플랫폼 제공 시스템
# 📌 출원번호: 1020190016213
#
# 📌 특허내용: 본 발명에 따른 가상현실 기반의 통합 교육 서비스 플랫폼 제공 시스템은, 중앙 관제서버와 통신 가능한 것으로, 일 측에 마이크 및 스피커가 구비되며 수험생의 두부(頭部)에 착용된 상태에서 가상현실 교육 컨텐츠를 실행하는 헤드 마운트 디스플레이; 수험생으로부터 목표대학정보를 포함하는 학생정보를 입력받는 학생가입부 및, 전문가로부터 합격대학정보를 포함하는 전문가정보를 입력받는 전문가가입부를 포함하는 가입모듈과, 복수의 상기 전문가 중 적어도 어느 하나와 상기 수험생을 매칭하는 매칭처리부 및, 상기 수험생과 매칭 처리된 상기 전문가를 가상 입학사정관으로 설정하는 면접관설정부를 포함하는 매칭모듈 및, 가상현실 교육 컨텐츠를 생성하여 저장하는 데이터베이스와, 상기 가상현실 교육 컨텐츠 상에 접속한 상기 가상 입학사정관과 상기 수험생을 연결 처리하여 면접을 수행하는 면접수행모듈과, 상기 면접이 종료됨에 따라 상기 가상 입학사정관으로부터 평가정보를 입력받는 평가정보입력부 및, 상기 평가정보를 상기 수험생에게 제공하는 결과제공부를 포함하는 면접결과안내모듈을 구비한 중앙관제서버;를 포함하는 것을 특징으로 한다.
#
# 📌 특허등록상태: 소멸
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190016213
#
# 📌 번호: 293
#
# 📄 발명명: 온라인 교육 컨텐츠 제작 플랫폼, 온라인 교육 컨텐츠의 제작 방법, 이를 이용하여 제작된 온라인 교육 컨텐츠가 저장된 데이터베이스 및 이를 활용한 온라인 교육 컨텐츠 제공 플랫폼
# 📌 출원번호: 1020230033683
#
# 📌 특허내용: 온라인 교육 컨텐츠 제작 플랫폼 및 제작 방법이 제공된다. 강의 영상과 강의 음성이 통합된 통합 컨텐츠에서 강의자의 모션 또는 음성을 인식하고, 상기 통합 컨텐츠 중 적어도 일부를 추출하여 온라인 교육 컨텐츠를 제어부에 저장할 수 있어, 모션 또는 음성 인식에 기반하여 자동으로 영상을 편집할 수 있다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230033683
#
# 📌 번호: 294
#
# 📄 발명명: 스마트 러닝 플랫폼 시스템 및 스마트 러닝 플랫폼 시스템에서 교육 서비스 제공 방법
# 📌 출원번호: 1020120122443
#
# 📌 특허내용: 본 발명은 온라인 교육 서비스시 통신 서비스 시스템의 인프라를 활용하여 교육 서비스 제공자와 교육 서비스 소비자가 자유롭게 이용할 수 있는 학습 플랫폼을 제공하는 시스템에 관한 것이다.  본 발명에 따르면, 교육 서비스를 등록받고 학습 사용자들에게 N-스크린 서비스를 통해 온라인 상으로 교육 서비스를 제공할 수 있도록 하는 플랫폼 시스템으로서, 교육 서비스 제공측에 학습 콘텐츠 및 교육 서비스를 포함한 학습 상품을 등록하도록 하는 학습 서비스 등록 모듈; 등록된 학습 상품의 목록을 제공하고, 사용자에게 원하는 학습 상품을 구매하도록 하는 학습 서비스 판매 모듈; 등록된 학습 상품에 대한 N-스크린 서비스를 제공하는 어플리케이션을 제공하는 N-스크린 APP 모듈; 및 플랫폼 관리 및 등록된 학습 상품의 서비스를 제공하기 위한 통신 서비스 시스템과의 인터페이스 연동을 지원하는 통신 플랫폼 지원 모듈;을 포함하는 스마트 러닝 플랫폼 시스템이 개시된다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020120122443
#
# 📌 번호: 295
#
# 📄 발명명: 인공지능 기반의 인앱 구조 교육 경험 플랫폼 시스템 및 그 방법
# 📌 출원번호: 1020240059549
#
# 📌 특허내용: 본 발명은 학습자 본인이 소유하고 있는 컴퓨터나 스마트 폰 등의 기기로 플랫폼에 접속하여 다양한 교육용 앱이 제공하는 학습 프로그램의 학습이 가능하고, 개별 앱 마다 회원가입, 로그인 절차를 거치지 않고 플랫폼에 한번의 회원가입 및 로그인 만으로 다양한 교육용 앱이 제공하는 학습 프로그램의 학습이 가능한 인공지능 기반의 인앱 구조 교육 경험 플랫폼 시스템 및 그 방법에 관한 것이다.  본 발명은 플랫폼에 가입한 회원들의 정보를 분석하여 과목별 맞춤학습목표를 제공하며, 회원들의 학습 데이터와 교육용 앱의 학습 프로그램에 대한 정보를 인공지능으로 분석하여 회원의 과목별 학습수준을 진단하고 회원에게 과목별로 도움(학습 프로그램 추천, 선행학습 추천)이 되는 정보를 제공함으로써 학습자에게 맞춤형 컨설팅이 가능하다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020240059549
#
# 📌 번호: 296
#
# 📄 발명명: TPM을 활용한 신뢰 플랫폼 개발 교육을 위한 키트
# 📌 출원번호: 1020180136595
#
# 📌 특허내용: 본 발명은 TPM을 활용한 신뢰 플랫폼 개발 교육을 위한 키트에 관한 것이다.  또한, 본 발명에 따르면, 교육용 보드 개발용 소프트웨어가 설치되어 있으며, 사용자가 교육용 보드 개발용 소프트웨어를 이용하여 교육용 제어 프로그램을 구현하고 컴파일하는 컴퓨터; 상기 컴퓨터에서 개발된 교육용 제어 프로그램을 실행하여 트레이닝 보드를 제어하는 메인 컨트롤러 보드; 상기 메인 컨트롤러 보드에 결착되어 있으며, 상기 메인 컨트롤러 보드의 제어에 따라 실행 결과를 보여주는 트레이닝 보드; 및 상기 메인 컨트롤러 보드와 연동되어 인증(Authentication), 암호(Cryptography), 데이터 보호(Data Protection), 플랫폼 보호(Platform Protection) 및 물리적 보호(Physical Protection) 기능을 수행하는 신뢰 플랫폼 모듈 보드를 포함하는 TPM을 활용한 신뢰 플랫폼 개발 교육을 위한 키트가 제공된다.
#
# 📌 특허등록상태: 등록
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020180136595
#
# 📌 번호: 297
#
# 📄 발명명: 맞춤형 무용 및 운동을 접목한 외국어 교육 영상 플랫폼 제공방법, 장치 및 시스템
# 📌 출원번호: 1020230086909
#
# 📌 특허내용: 일실시예에 따르면, 맞춤형 무용 및 운동을 접목한 외국어 교육 영상 플랫폼 제공 방법은 제1 사용자 단말로부터 맞춤형 무용 및 운동을 접목한 외국어 교육 영상 플랫폼에 대한 접속 요청을 수신하는 단계; 제1 사용자의 접속 요청에 응답하여, 제1 사용자에 대응하는 제1 무용 및 운동과 외국어 목표를 획득하는 단계; 제1 무용 및 운동과 외국어 목표에 대응하는 영상 카테고리 획득하는 단계; 영상 카테고리에 대응하는 무용 및 운동을 접목한 외국어 교육 영상 콘텐츠들을 추출하는 단계; 및 추출된 무용 및 운동을 접목한 외국어 교육 영상 콘텐츠들 중 적어도 하나 이상의 콘텐츠를 제1 사용자 단말로 제공하는 단계를 포함한다.  제1 사용자에 대응하는 제1 무용 및 운동과 외국어 목표를 획득하는 단계는 제1 사용자단말로부터 제1 사용자의 기본 정보를 획득하는 단계; 제1 사용자의 기본 정보를 기초로, 제1 사용자의 기본 정보와 비슷한 사용자들의 무용 및 운동과 외국어 목표를 추출하는 단계; 추출된 무용 및 운동과 외국어 목표를 기초로, 무용 및 운동에 접목한 외국어 교육 영상 콘텐츠를 생성하는 단계; 및 생성된 외국어 교육을 접목한 무용 및 운동 목표에 대응하는 비율을 기초로, 제1 사용자에게 적합한 외국어 교육을 접목한 무용 및 운동 목표를 선정 및 추천하는 단계를 포함한다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020230086909
#
# 📌 번호: 298
#
# 📄 발명명: 교육 콘텐츠 관련 서비스를 위한 인터넷 플랫폼 시스템 및 관련 방법
# 📌 출원번호: 1020190179833
#
# 📌 특허내용: 교육 콘텐츠 관련 서비스를 위한 인터넷 플랫폼 시스템 및 관련 방법에 관해 개시되어 있다. 개시된 인터넷 플랫폼 시스템은 플랫폼 서버를 포함할 수 있고, 상기 플랫폼 서버는 단말기를 통해 상기 플랫폼 서버에 접속한 사용자들의 콘텐츠 이용/구매 정보를 분석하는 콘텐츠 이용/구매 정보 분석부, 상기 사용자들의 위치 관련 정보를 취득하는 위치 관련 정보 획득부, 상기 사용자들 중 일부가 개설한 복수의 스터디 모임의 정보를 저장하는 스터디 모임 정보 저장부 및 상기 콘텐츠 이용/구매 정보와 상기 위치 관련 정보 및 상기 스터디 모임의 정보를 기반하여 소정의 개별 사용자에게 상기 복수의 스터디 모임 중 본인에게 상대적으로 적합한 스터디 모임을 선택할 수 있도록 스터디 모임 관련 서비스를 제공하는 스터디 모임 관련 서비스 제공부를 포함할 수 있다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020190179833
#
# 📌 번호: 299
#
# 📄 발명명: 한국어 교육 온라인 플랫폼 제공 방법 및 이를 위한 서버
# 📌 출원번호: 1020210172220
#
# 📌 특허내용: 본 발명의 실시예에 따른 한국어 교육 온라인 플랫폼을 제공하는 서버는 서버에 접속된 학습자 계정의 모국어에 관한 정보를 수신하는 통신부 및 학습자의 모국어에 관한 정보에 기반하여, 학습자에 관한 정보를 서버에 등록하고, 학습자에 관한 정보에 기반하여 상기 학습자 계정과 학습자 계정을 교육시키기 위한 강사 계정을 매칭시키는 제어부를 포함할 수 있다.
#
# 📌 특허등록상태: 공개
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020210172220
#
# 📌 번호: 300
#
# 📄 발명명: 교육과 배움에 특화된 소셜네트워크서비스 플랫폼
# 📌 출원번호: 1020220069835
#
# 📌 특허내용: 본 발명은 클라우드 기반으로 구현되는 교육과 배움에 특화된 소셜네트워크서비스 플랫폼 구성에 관한 것으로 구체적으로는 인터넷에 연결된 컴퓨터, 스마트폰, 자동차, 모바일 기기 등을 대상으로 제공되는 교육과 배움에 특화된 소셜네트워크서비스 플랫폼이 제공할 수 있는 서비스와 비즈니스 모델에 관한 것을 기술하고 있다. 동 플랫폼은 이를 위해 사용자 계정 데이터베이스(DB), 신뢰도 평가 기능, 기관 등록 기능, 기관별 커뮤니티 서비스 기능, 화상회의 서비스 기능, 학습자료 등록/검색 데이터베이스(DB) 기능, 튜터 중계 및 학습자료 거래 서비스 기능, 광고 서비스 기능 등으로 구성된다. 본 발명이 추구하는 것은 사용자들이 기존의 학습서나 참고서 위주의 재미없는 교육을 탈피하여 누구나 포스팅 할 수 있지만 평가 기능을 통해 다수로 부터 신뢰도가 검증된 재미있고 참신한 짧은 동영상, 이미지, 학습 자료 등의 공유와 거래를 통해 재미있게 교육과 배움을 하면서 사용자가 수익도 창출 할 수 있는 것을 목적으로 한다.
#
# 📌 특허등록상태: 거절
# 🔗 상세보기: https://kpat.kipris.or.kr/kpat/biblioa.do?method=biblio&applicationNumber=1020220069835
#
#
# 🧠 사용자 질문과 유사한 특허 Top 5:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 229
#     227 # 6. 유사 특허 찾기
#     228 print("\n🧠 사용자 질문과 유사한 특허 Top 5:\n")
# --> 229 similarities = find_similar_patents(user_question, unique_patents)
#     230 similar_patents_output = format_similar_patents(similarities)
#     231 print(similar_patents_output)
#
# Cell In[9], line 127, in find_similar_patents(user_question, patents, top_n)
#     125 abstract = item.get('astrtCont', '내용 없음')
#     126 text = title + " " + abstract
# --> 127 patent_emb = get_embedding(text)
#     129 similarity = cosine_similarity(user_emb, patent_emb)
#     130 similarities.append((item, similarity))
#
# Cell In[9], line 108, in get_embedding(text)
#     107 def get_embedding(text):
# --> 108   response = client.embeddings.create(
#     109       model="text-embedding-ada-002",
#     110       input=text
#     111   )
#     112   return np.array(response.data[0].embedding)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\resources\embeddings.py:128, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     122             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     123                 base64.b64decode(data), dtype="float32"
#     124             ).tolist()
#     126     return obj
# --> 128 return self._post(
#     129     "/embeddings",
#     130     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     131     options=make_request_options(
#     132         extra_headers=extra_headers,
#     133         extra_query=extra_query,
#     134         extra_body=extra_body,
#     135         timeout=timeout,
#     136         post_parser=parser,
#     137     ),
#     138     cast_to=CreateEmbeddingResponse,
#     139 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)   1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\_base_client.py:969, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     967 response = None
#     968 try:
# --> 969     response = self._client.send(
#     970         request,
#     971         stream=stream or self._should_stream_response_body(request=request),
#     972         **kwargs,
#     973     )
#     974 except httpx.TimeoutException as err:
#     975     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpx\_transports\default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)    233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
